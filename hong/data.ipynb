# %%
from flask import Flask, jsonify, render_template
import pandas as pd
import pymongo
from pymongo import MongoClient

# %%
client = MongoClient('mongodb://localhost:27017/')
db = client.heart_data

collection = db.train_values

# %%
list = []
for obj in collection.find():
    obj.pop("_id")
    list.append(obj)

# %%
list
# Out:
# [{'patient_id': '0z64un',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'normal',
#   'resting_blood_pressure': '128',
#   'chest_pain_type': '2',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '308',
#   'oldpeak_eq_st_depression': '0.0',
#   'sex': '1',
#   'age': '45',
#   'max_heart_rate_achieved': '170',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'ryoo3j',
#   'slope_of_peak_exercise_st_segment': '2',
#   'thal': 'normal',
#   'resting_blood_pressure': '110',
#   'chest_pain_type': '3',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '214',
#   'oldpeak_eq_st_depression': '1.6',
#   'sex': '0',
#   'age': '54',
#   'max_heart_rate_achieved': '158',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'yt1s1x',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'normal',
#   'resting_blood_pressure': '125',
#   'chest_pain_type': '4',
#   'num_major_vessels': '3',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '304',
#   'oldpeak_eq_st_depression': '0.0',
#   'sex': '1',
#   'age': '77',
#   'max_heart_rate_achieved': '162',
#   'exercise_induced_angina': '1'},
#  {'patient_id': 'l2xjde',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': '152',
#   'chest_pain_type': '4',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '223',
#   'oldpeak_eq_st_depression': '0.0',
#   'sex': '1',
#   'age': '40',
#   'max_heart_rate_achieved': '181',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'oyt4ek',
#   'slope_of_peak_exercise_st_segment': '3',
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': '178',
#   'chest_pain_type': '1',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '270',
#   'oldpeak_eq_st_depression': '4.2',
#   'sex': '1',
#   'age': '59',
#   'max_heart_rate_achieved': '145',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'ldukkw',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'normal',
#   'resting_blood_pressure': '130',
#   'chest_pain_type': '3',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '180',
#   'oldpeak_eq_st_depression': '0.0',
#   'sex': '1',
#   'age': '42',
#   'max_heart_rate_achieved': '150',
#   'exercise_induced_angina': '0'},
#  {'patient_id': '2gbyh9',
#   'slope_of_peak_exercise_st_segment': '2',
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': '150',
#   'chest_pain_type': '4',
#   'num_major_vessels': '2',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '258',
#   'oldpeak_eq_st_depression': '2.6',
#   'sex': '0',
#   'age': '60',
#   'max_heart_rate_achieved': '157',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'daa9kp',
#   'slope_of_peak_exercise_st_segment': '2',
#   'thal': 'fixed_defect',
#   'resting_blood_pressure': '150',
#   'chest_pain_type': '4',
#   'num_major_vessels': '1',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '276',
#   'oldpeak_eq_st_depression': '0.6',
#   'sex': '1',
#   'age': '57',
#   'max_heart_rate_achieved': '112',
#   'exercise_induced_angina': '1'},
#  {'patient_id': '3nwy2n',
#   'slope_of_peak_exercise_st_segment': '3',
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': '170',
#   'chest_pain_type': '4',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '326',
#   'oldpeak_eq_st_depression': '3.4',
#   'sex': '1',
#   'age': '59',
#   'max_heart_rate_achieved': '140',
#   'exercise_induced_angina': '1'},
#  {'patient_id': '1r508r',
#   'slope_of_peak_exercise_st_segment': '2',
#   'thal': 'normal',
#   'resting_blood_pressure': '120',
#   'chest_pain_type': '3',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '219',
#   'oldpeak_eq_st_depression': '1.6',
#   'sex': '0',
#   'age': '50',
#   'max_heart_rate_achieved': '158',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'ldg4b9',
#   'slope_of_peak_exercise_st_segment': '2',
#   'thal': 'normal',
#   'resting_blood_pressure': '120',
#   'chest_pain_type': '4',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '302',
#   'oldpeak_eq_st_depression': '0.4',
#   'sex': '1',
#   'age': '66',
#   'max_heart_rate_achieved': '151',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'xc17yq',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'normal',
#   'resting_blood_pressure': '140',
#   'chest_pain_type': '4',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '226',
#   'oldpeak_eq_st_depression': '0.0',
#   'sex': '1',
#   'age': '42',
#   'max_heart_rate_achieved': '178',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'mpggsq',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'normal',
#   'resting_blood_pressure': '140',
#   'chest_pain_type': '3',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '335',
#   'oldpeak_eq_st_depression': '0.0',
#   'sex': '1',
#   'age': '64',
#   'max_heart_rate_achieved': '158',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'zlyac8',
#   'slope_of_peak_exercise_st_segment': '2',
#   'thal': 'normal',
#   'resting_blood_pressure': '138',
#   'chest_pain_type': '4',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '236',
#   'oldpeak_eq_st_depression': '0.2',
#   'sex': '0',
#   'age': '45',
#   'max_heart_rate_achieved': '152',
#   'exercise_induced_angina': '1'},
#  {'patient_id': 'f06u72',
#   'slope_of_peak_exercise_st_segment': '2',
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': '120',
#   'chest_pain_type': '1',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '231',
#   'oldpeak_eq_st_depression': '3.8',
#   'sex': '1',
#   'age': '38',
#   'max_heart_rate_achieved': '182',
#   'exercise_induced_angina': '1'},
#  {'patient_id': '2fv3rc',
#   'slope_of_peak_exercise_st_segment': '2',
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': '144',
#   'chest_pain_type': '4',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '200',
#   'oldpeak_eq_st_depression': '0.9',
#   'sex': '1',
#   'age': '50',
#   'max_heart_rate_achieved': '126',
#   'exercise_induced_angina': '1'},
#  {'patient_id': 'qyrkxn',
#   'slope_of_peak_exercise_st_segment': '2',
#   'thal': 'normal',
#   'resting_blood_pressure': '130',
#   'chest_pain_type': '2',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '234',
#   'oldpeak_eq_st_depression': '0.6',
#   'sex': '0',
#   'age': '45',
#   'max_heart_rate_achieved': '175',
#   'exercise_induced_angina': '0'},
#  {'patient_id': '237mql',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': '130',
#   'chest_pain_type': '4',
#   'num_major_vessels': '1',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '253',
#   'oldpeak_eq_st_depression': '1.4',
#   'sex': '1',
#   'age': '60',
#   'max_heart_rate_achieved': '144',
#   'exercise_induced_angina': '1'},
#  {'patient_id': 'mc750a',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'normal',
#   'resting_blood_pressure': '130',
#   'chest_pain_type': '2',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '204',
#   'oldpeak_eq_st_depression': '0.0',
#   'sex': '1',
#   'age': '29',
#   'max_heart_rate_achieved': '202',
#   'exercise_induced_angina': '0'},
#  {'patient_id': '30v796',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'normal',
#   'resting_blood_pressure': '136',
#   'chest_pain_type': '2',
#   'num_major_vessels': '2',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '1',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '319',
#   'oldpeak_eq_st_depression': '0.0',
#   'sex': '0',
#   'age': '58',
#   'max_heart_rate_achieved': '152',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'cvux3j',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'normal',
#   'resting_blood_pressure': '160',
#   'chest_pain_type': '2',
#   'num_major_vessels': '2',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '302',
#   'oldpeak_eq_st_depression': '0.4',
#   'sex': '0',
#   'age': '71',
#   'max_heart_rate_achieved': '162',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'k8899q',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': '108',
#   'chest_pain_type': '4',
#   'num_major_vessels': '3',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '1',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '233',
#   'oldpeak_eq_st_depression': '0.1',
#   'sex': '1',
#   'age': '52',
#   'max_heart_rate_achieved': '147',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'jhdvtb',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'normal',
#   'resting_blood_pressure': '106',
#   'chest_pain_type': '4',
#   'num_major_vessels': '2',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '223',
#   'oldpeak_eq_st_depression': '0.3',
#   'sex': '0',
#   'age': '67',
#   'max_heart_rate_achieved': '142',
#   'exercise_induced_angina': '0'},
#  {'patient_id': '5g9v0h',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'fixed_defect',
#   'resting_blood_pressure': '160',
#   'chest_pain_type': '4',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '228',
#   'oldpeak_eq_st_depression': '2.3',
#   'sex': '1',
#   'age': '66',
#   'max_heart_rate_achieved': '138',
#   'exercise_induced_angina': '0'},
#  {'patient_id': '83asqd',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'normal',
#   'resting_blood_pressure': '156',
#   'chest_pain_type': '2',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '245',
#   'oldpeak_eq_st_depression': '0.0',
#   'sex': '1',
#   'age': '70',
#   'max_heart_rate_achieved': '143',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'gla0im',
#   'slope_of_peak_exercise_st_segment': '2',
#   'thal': 'normal',
#   'resting_blood_pressure': '120',
#   'chest_pain_type': '3',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '211',
#   'oldpeak_eq_st_depression': '1.5',
#   'sex': '0',
#   'age': '68',
#   'max_heart_rate_achieved': '115',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'zzmfh7',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'normal',
#   'resting_blood_pressure': '128',
#   'chest_pain_type': '4',
#   'num_major_vessels': '1',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '303',
#   'oldpeak_eq_st_depression': '0.0',
#   'sex': '0',
#   'age': '57',
#   'max_heart_rate_achieved': '159',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'f4g1ay',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'normal',
#   'resting_blood_pressure': '128',
#   'chest_pain_type': '2',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '1',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '205',
#   'oldpeak_eq_st_depression': '0.0',
#   'sex': '1',
#   'age': '52',
#   'max_heart_rate_achieved': '184',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'lek9q9',
#   'slope_of_peak_exercise_st_segment': '2',
#   'thal': 'normal',
#   'resting_blood_pressure': '140',
#   'chest_pain_type': '3',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '185',
#   'oldpeak_eq_st_depression': '3.0',
#   'sex': '1',
#   'age': '60',
#   'max_heart_rate_achieved': '155',
#   'exercise_induced_angina': '0'},
#  {'patient_id': '8265rl',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'normal',
#   'resting_blood_pressure': '110',
#   'chest_pain_type': '3',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '175',
#   'oldpeak_eq_st_depression': '0.6',
#   'sex': '1',
#   'age': '51',
#   'max_heart_rate_achieved': '123',
#   'exercise_induced_angina': '0'},
#  {'patient_id': '6017a1',
#   'slope_of_peak_exercise_st_segment': '2',
#   'thal': 'normal',
#   'resting_blood_pressure': '130',
#   'chest_pain_type': '3',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '214',
#   'oldpeak_eq_st_depression': '2.0',
#   'sex': '1',
#   'age': '41',
#   'max_heart_rate_achieved': '168',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'z7xkou',
#   'slope_of_peak_exercise_st_segment': '2',
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': '150',
#   'chest_pain_type': '4',
#   'num_major_vessels': '3',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '225',
#   'oldpeak_eq_st_depression': '1.0',
#   'sex': '0',
#   'age': '65',
#   'max_heart_rate_achieved': '114',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'k7ef7h',
#   'slope_of_peak_exercise_st_segment': '3',
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': '140',
#   'chest_pain_type': '4',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '1',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '203',
#   'oldpeak_eq_st_depression': '3.1',
#   'sex': '1',
#   'age': '53',
#   'max_heart_rate_achieved': '155',
#   'exercise_induced_angina': '1'},
#  {'patient_id': '0n5fu0',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'normal',
#   'resting_blood_pressure': '180',
#   'chest_pain_type': '4',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '325',
#   'oldpeak_eq_st_depression': '0.0',
#   'sex': '0',
#   'age': '64',
#   'max_heart_rate_achieved': '154',
#   'exercise_induced_angina': '1'},
#  {'patient_id': '55xksg',
#   'slope_of_peak_exercise_st_segment': '2',
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': '112',
#   'chest_pain_type': '3',
#   'num_major_vessels': '1',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '230',
#   'oldpeak_eq_st_depression': '2.5',
#   'sex': '1',
#   'age': '58',
#   'max_heart_rate_achieved': '165',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'pjgqa3',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'normal',
#   'resting_blood_pressure': '122',
#   'chest_pain_type': '4',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '222',
#   'oldpeak_eq_st_depression': '0.0',
#   'sex': '1',
#   'age': '48',
#   'max_heart_rate_achieved': '186',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'xkdz7j',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': '150',
#   'chest_pain_type': '3',
#   'num_major_vessels': '1',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '1',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '126',
#   'oldpeak_eq_st_depression': '0.2',
#   'sex': '1',
#   'age': '57',
#   'max_heart_rate_achieved': '173',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'tpuevg',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'normal',
#   'resting_blood_pressure': '124',
#   'chest_pain_type': '4',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '209',
#   'oldpeak_eq_st_depression': '0.0',
#   'sex': '0',
#   'age': '62',
#   'max_heart_rate_achieved': '163',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'ascl42',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'normal',
#   'resting_blood_pressure': '120',
#   'chest_pain_type': '2',
#   'num_major_vessels': '1',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '269',
#   'oldpeak_eq_st_depression': '0.2',
#   'sex': '0',
#   'age': '74',
#   'max_heart_rate_achieved': '121',
#   'exercise_induced_angina': '1'},
#  {'patient_id': '1xwoe6',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': '128',
#   'chest_pain_type': '4',
#   'num_major_vessels': '1',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '255',
#   'oldpeak_eq_st_depression': '0.0',
#   'sex': '1',
#   'age': '52',
#   'max_heart_rate_achieved': '161',
#   'exercise_induced_angina': '1'},
#  {'patient_id': 'ty4ik8',
#   'slope_of_peak_exercise_st_segment': '2',
#   'thal': 'normal',
#   'resting_blood_pressure': '150',
#   'chest_pain_type': '3',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '1',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '243',
#   'oldpeak_eq_st_depression': '1.0',
#   'sex': '1',
#   'age': '61',
#   'max_heart_rate_achieved': '137',
#   'exercise_induced_angina': '1'},
#  {'patient_id': 'gx6yxl',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'normal',
#   'resting_blood_pressure': '135',
#   'chest_pain_type': '3',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '252',
#   'oldpeak_eq_st_depression': '0.0',
#   'sex': '0',
#   'age': '63',
#   'max_heart_rate_achieved': '172',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'hlmts5',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'normal',
#   'resting_blood_pressure': '110',
#   'chest_pain_type': '3',
#   'num_major_vessels': '1',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '1',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '265',
#   'oldpeak_eq_st_depression': '0.0',
#   'sex': '0',
#   'age': '71',
#   'max_heart_rate_achieved': '130',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'yx0q6k',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'normal',
#   'resting_blood_pressure': '140',
#   'chest_pain_type': '3',
#   'num_major_vessels': '1',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '1',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '417',
#   'oldpeak_eq_st_depression': '0.8',
#   'sex': '0',
#   'age': '65',
#   'max_heart_rate_achieved': '157',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'ep1o51',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'normal',
#   'resting_blood_pressure': '108',
#   'chest_pain_type': '3',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '267',
#   'oldpeak_eq_st_depression': '0.0',
#   'sex': '0',
#   'age': '54',
#   'max_heart_rate_achieved': '167',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'gj1e5z',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': '124',
#   'chest_pain_type': '2',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '261',
#   'oldpeak_eq_st_depression': '0.3',
#   'sex': '1',
#   'age': '57',
#   'max_heart_rate_achieved': '141',
#   'exercise_induced_angina': '0'},
#  {'patient_id': '6219kl',
#   'slope_of_peak_exercise_st_segment': '2',
#   'thal': 'normal',
#   'resting_blood_pressure': '125',
#   'chest_pain_type': '3',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '1',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '245',
#   'oldpeak_eq_st_depression': '2.4',
#   'sex': '1',
#   'age': '51',
#   'max_heart_rate_achieved': '166',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'rp9g6x',
#   'slope_of_peak_exercise_st_segment': '2',
#   'thal': 'normal',
#   'resting_blood_pressure': '112',
#   'chest_pain_type': '4',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '149',
#   'oldpeak_eq_st_depression': '1.6',
#   'sex': '0',
#   'age': '71',
#   'max_heart_rate_achieved': '125',
#   'exercise_induced_angina': '0'},
#  {'patient_id': '1aeaff',
#   'slope_of_peak_exercise_st_segment': '2',
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': '120',
#   'chest_pain_type': '2',
#   'num_major_vessels': '1',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '281',
#   'oldpeak_eq_st_depression': '1.4',
#   'sex': '1',
#   'age': '62',
#   'max_heart_rate_achieved': '103',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'y3prof',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'normal',
#   'resting_blood_pressure': '105',
#   'chest_pain_type': '2',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '204',
#   'oldpeak_eq_st_depression': '0.0',
#   'sex': '0',
#   'age': '46',
#   'max_heart_rate_achieved': '172',
#   'exercise_induced_angina': '0'},
#  {'patient_id': '3drd48',
#   'slope_of_peak_exercise_st_segment': '2',
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': '140',
#   'chest_pain_type': '4',
#   'num_major_vessels': '2',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '311',
#   'oldpeak_eq_st_depression': '1.8',
#   'sex': '1',
#   'age': '46',
#   'max_heart_rate_achieved': '120',
#   'exercise_induced_angina': '1'},
#  {'patient_id': 'ejo7p3',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'normal',
#   'resting_blood_pressure': '130',
#   'chest_pain_type': '3',
#   'num_major_vessels': '1',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '315',
#   'oldpeak_eq_st_depression': '1.9',
#   'sex': '1',
#   'age': '43',
#   'max_heart_rate_achieved': '162',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'r7y4i1',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': '130',
#   'chest_pain_type': '4',
#   'num_major_vessels': '3',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '1',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '330',
#   'oldpeak_eq_st_depression': '1.8',
#   'sex': '1',
#   'age': '63',
#   'max_heart_rate_achieved': '132',
#   'exercise_induced_angina': '1'},
#  {'patient_id': 'mznwxv',
#   'slope_of_peak_exercise_st_segment': '2',
#   'thal': 'fixed_defect',
#   'resting_blood_pressure': '130',
#   'chest_pain_type': '3',
#   'num_major_vessels': '1',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '1',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '256',
#   'oldpeak_eq_st_depression': '0.6',
#   'sex': '1',
#   'age': '56',
#   'max_heart_rate_achieved': '142',
#   'exercise_induced_angina': '1'},
#  {'patient_id': '27oevk',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'normal',
#   'resting_blood_pressure': '130',
#   'chest_pain_type': '4',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '330',
#   'oldpeak_eq_st_depression': '0.0',
#   'sex': '0',
#   'age': '61',
#   'max_heart_rate_achieved': '169',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'jwqi3k',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'normal',
#   'resting_blood_pressure': '130',
#   'chest_pain_type': '3',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '233',
#   'oldpeak_eq_st_depression': '0.4',
#   'sex': '1',
#   'age': '44',
#   'max_heart_rate_achieved': '179',
#   'exercise_induced_angina': '1'},
#  {'patient_id': '328lkl',
#   'slope_of_peak_exercise_st_segment': '2',
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': '110',
#   'chest_pain_type': '4',
#   'num_major_vessels': '1',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '239',
#   'oldpeak_eq_st_depression': '2.8',
#   'sex': '1',
#   'age': '54',
#   'max_heart_rate_achieved': '126',
#   'exercise_induced_angina': '1'},
#  {'patient_id': 'tlk9o8',
#   'slope_of_peak_exercise_st_segment': '2',
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': '120',
#   'chest_pain_type': '4',
#   'num_major_vessels': '2',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '267',
#   'oldpeak_eq_st_depression': '1.8',
#   'sex': '1',
#   'age': '62',
#   'max_heart_rate_achieved': '99',
#   'exercise_induced_angina': '1'},
#  {'patient_id': 'aq2vrq',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'normal',
#   'resting_blood_pressure': '120',
#   'chest_pain_type': '2',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '295',
#   'oldpeak_eq_st_depression': '0.0',
#   'sex': '1',
#   'age': '42',
#   'max_heart_rate_achieved': '162',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'ilogfb',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'normal',
#   'resting_blood_pressure': '110',
#   'chest_pain_type': '4',
#   'num_major_vessels': '1',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '197',
#   'oldpeak_eq_st_depression': '0.0',
#   'sex': '1',
#   'age': '44',
#   'max_heart_rate_achieved': '177',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'rv6siv',
#   'slope_of_peak_exercise_st_segment': '2',
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': '115',
#   'chest_pain_type': '3',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '564',
#   'oldpeak_eq_st_depression': '1.6',
#   'sex': '0',
#   'age': '67',
#   'max_heart_rate_achieved': '160',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'm2a4i9',
#   'slope_of_peak_exercise_st_segment': '2',
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': '130',
#   'chest_pain_type': '4',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '305',
#   'oldpeak_eq_st_depression': '1.2',
#   'sex': '0',
#   'age': '51',
#   'max_heart_rate_achieved': '142',
#   'exercise_induced_angina': '1'},
#  {'patient_id': 'pwigd8',
#   'slope_of_peak_exercise_st_segment': '3',
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': '130',
#   'chest_pain_type': '4',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '1',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '283',
#   'oldpeak_eq_st_depression': '1.6',
#   'sex': '1',
#   'age': '56',
#   'max_heart_rate_achieved': '103',
#   'exercise_induced_angina': '1'},
#  {'patient_id': 'qwapdq',
#   'slope_of_peak_exercise_st_segment': '2',
#   'thal': 'normal',
#   'resting_blood_pressure': '112',
#   'chest_pain_type': '2',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '160',
#   'oldpeak_eq_st_depression': '0.0',
#   'sex': '0',
#   'age': '45',
#   'max_heart_rate_achieved': '138',
#   'exercise_induced_angina': '0'},
#  {'patient_id': '4sd1xn',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'normal',
#   'resting_blood_pressure': '110',
#   'chest_pain_type': '4',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '254',
#   'oldpeak_eq_st_depression': '0.0',
#   'sex': '0',
#   'age': '50',
#   'max_heart_rate_achieved': '159',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'nck22c',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': '126',
#   'chest_pain_type': '4',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '282',
#   'oldpeak_eq_st_depression': '0.0',
#   'sex': '1',
#   'age': '35',
#   'max_heart_rate_achieved': '156',
#   'exercise_induced_angina': '1'},
#  {'patient_id': 'm6zksp',
#   'slope_of_peak_exercise_st_segment': '2',
#   'thal': 'normal',
#   'resting_blood_pressure': '130',
#   'chest_pain_type': '4',
#   'num_major_vessels': '3',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '322',
#   'oldpeak_eq_st_depression': '2.4',
#   'sex': '1',
#   'age': '70',
#   'max_heart_rate_achieved': '109',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'f70grj',
#   'slope_of_peak_exercise_st_segment': '2',
#   'thal': 'normal',
#   'resting_blood_pressure': '115',
#   'chest_pain_type': '4',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '303',
#   'oldpeak_eq_st_depression': '1.2',
#   'sex': '1',
#   'age': '43',
#   'max_heart_rate_achieved': '181',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'k1art8',
#   'slope_of_peak_exercise_st_segment': '2',
#   'thal': 'normal',
#   'resting_blood_pressure': '135',
#   'chest_pain_type': '2',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '250',
#   'oldpeak_eq_st_depression': '1.4',
#   'sex': '0',
#   'age': '55',
#   'max_heart_rate_achieved': '161',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'mcwqgs',
#   'slope_of_peak_exercise_st_segment': '2',
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': '120',
#   'chest_pain_type': '3',
#   'num_major_vessels': '3',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '188',
#   'oldpeak_eq_st_depression': '2.0',
#   'sex': '1',
#   'age': '49',
#   'max_heart_rate_achieved': '139',
#   'exercise_induced_angina': '0'},
#  {'patient_id': '3jsjqk',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'normal',
#   'resting_blood_pressure': '120',
#   'chest_pain_type': '2',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '220',
#   'oldpeak_eq_st_depression': '0.0',
#   'sex': '1',
#   'age': '44',
#   'max_heart_rate_achieved': '170',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'ik7hfs',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'normal',
#   'resting_blood_pressure': '112',
#   'chest_pain_type': '4',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '204',
#   'oldpeak_eq_st_depression': '0.1',
#   'sex': '1',
#   'age': '47',
#   'max_heart_rate_achieved': '143',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'qwj1yf',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': '172',
#   'chest_pain_type': '3',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '1',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '199',
#   'oldpeak_eq_st_depression': '0.5',
#   'sex': '1',
#   'age': '52',
#   'max_heart_rate_achieved': '162',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'qvhk9e',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'normal',
#   'resting_blood_pressure': '120',
#   'chest_pain_type': '3',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '215',
#   'oldpeak_eq_st_depression': '0.0',
#   'sex': '0',
#   'age': '37',
#   'max_heart_rate_achieved': '170',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'igwnqo',
#   'slope_of_peak_exercise_st_segment': '2',
#   'thal': 'fixed_defect',
#   'resting_blood_pressure': '126',
#   'chest_pain_type': '3',
#   'num_major_vessels': '1',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '1',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '218',
#   'oldpeak_eq_st_depression': '2.2',
#   'sex': '1',
#   'age': '59',
#   'max_heart_rate_achieved': '134',
#   'exercise_induced_angina': '0'},
#  {'patient_id': '4v0q7o',
#   'slope_of_peak_exercise_st_segment': '2',
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': '178',
#   'chest_pain_type': '4',
#   'num_major_vessels': '2',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '1',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '228',
#   'oldpeak_eq_st_depression': '1.0',
#   'sex': '0',
#   'age': '66',
#   'max_heart_rate_achieved': '165',
#   'exercise_induced_angina': '1'},
#  {'patient_id': 'hh2awp',
#   'slope_of_peak_exercise_st_segment': '2',
#   'thal': 'normal',
#   'resting_blood_pressure': '136',
#   'chest_pain_type': '3',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '196',
#   'oldpeak_eq_st_depression': '0.1',
#   'sex': '0',
#   'age': '52',
#   'max_heart_rate_achieved': '169',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'vfjppl',
#   'slope_of_peak_exercise_st_segment': '2',
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': '124',
#   'chest_pain_type': '4',
#   'num_major_vessels': '1',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '266',
#   'oldpeak_eq_st_depression': '2.2',
#   'sex': '1',
#   'age': '54',
#   'max_heart_rate_achieved': '109',
#   'exercise_induced_angina': '1'},
#  {'patient_id': '6lu42b',
#   'slope_of_peak_exercise_st_segment': '2',
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': '145',
#   'chest_pain_type': '4',
#   'num_major_vessels': '2',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '282',
#   'oldpeak_eq_st_depression': '2.8',
#   'sex': '1',
#   'age': '60',
#   'max_heart_rate_achieved': '142',
#   'exercise_induced_angina': '1'},
#  {'patient_id': 'shiro4',
#   'slope_of_peak_exercise_st_segment': '2',
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': '130',
#   'chest_pain_type': '4',
#   'num_major_vessels': '1',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '254',
#   'oldpeak_eq_st_depression': '1.4',
#   'sex': '1',
#   'age': '63',
#   'max_heart_rate_achieved': '147',
#   'exercise_induced_angina': '0'},
#  {'patient_id': '3wl3z4',
#   'slope_of_peak_exercise_st_segment': '3',
#   'thal': 'normal',
#   'resting_blood_pressure': '130',
#   'chest_pain_type': '3',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '1',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '197',
#   'oldpeak_eq_st_depression': '1.2',
#   'sex': '1',
#   'age': '53',
#   'max_heart_rate_achieved': '152',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'ebioez',
#   'slope_of_peak_exercise_st_segment': '2',
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': '120',
#   'chest_pain_type': '4',
#   'num_major_vessels': '1',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '188',
#   'oldpeak_eq_st_depression': '1.4',
#   'sex': '1',
#   'age': '54',
#   'max_heart_rate_achieved': '113',
#   'exercise_induced_angina': '0'},
#  {'patient_id': '37c0vm',
#   'slope_of_peak_exercise_st_segment': '3',
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': '110',
#   'chest_pain_type': '2',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '229',
#   'oldpeak_eq_st_depression': '1.0',
#   'sex': '1',
#   'age': '48',
#   'max_heart_rate_achieved': '168',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'v52zcs',
#   'slope_of_peak_exercise_st_segment': '2',
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': '128',
#   'chest_pain_type': '4',
#   'num_major_vessels': '2',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '259',
#   'oldpeak_eq_st_depression': '3.0',
#   'sex': '1',
#   'age': '58',
#   'max_heart_rate_achieved': '130',
#   'exercise_induced_angina': '1'},
#  {'patient_id': '6nkcaw',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'normal',
#   'resting_blood_pressure': '130',
#   'chest_pain_type': '3',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '256',
#   'oldpeak_eq_st_depression': '0.5',
#   'sex': '0',
#   'age': '51',
#   'max_heart_rate_achieved': '149',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'hfp05i',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'normal',
#   'resting_blood_pressure': '118',
#   'chest_pain_type': '3',
#   'num_major_vessels': '3',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '149',
#   'oldpeak_eq_st_depression': '0.8',
#   'sex': '1',
#   'age': '49',
#   'max_heart_rate_achieved': '126',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'grfxwd',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'normal',
#   'resting_blood_pressure': '112',
#   'chest_pain_type': '3',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '268',
#   'oldpeak_eq_st_depression': '0.0',
#   'sex': '0',
#   'age': '41',
#   'max_heart_rate_achieved': '172',
#   'exercise_induced_angina': '1'},
#  {'patient_id': 'bvcxah',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': '140',
#   'chest_pain_type': '4',
#   'num_major_vessels': '1',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '177',
#   'oldpeak_eq_st_depression': '0.0',
#   'sex': '1',
#   'age': '59',
#   'max_heart_rate_achieved': '162',
#   'exercise_induced_angina': '1'},
#  {'patient_id': 'i49srr',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'normal',
#   'resting_blood_pressure': '150',
#   'chest_pain_type': '3',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '168',
#   'oldpeak_eq_st_depression': '1.6',
#   'sex': '1',
#   'age': '57',
#   'max_heart_rate_achieved': '174',
#   'exercise_induced_angina': '0'},
#  {'patient_id': '93dbhq',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'normal',
#   'resting_blood_pressure': '130',
#   'chest_pain_type': '2',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '262',
#   'oldpeak_eq_st_depression': '0.0',
#   'sex': '1',
#   'age': '55',
#   'max_heart_rate_achieved': '155',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'jscmp8',
#   'slope_of_peak_exercise_st_segment': '2',
#   'thal': 'normal',
#   'resting_blood_pressure': '134',
#   'chest_pain_type': '2',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '271',
#   'oldpeak_eq_st_depression': '0.0',
#   'sex': '0',
#   'age': '49',
#   'max_heart_rate_achieved': '162',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'zaytyf',
#   'slope_of_peak_exercise_st_segment': '2',
#   'thal': 'normal',
#   'resting_blood_pressure': '100',
#   'chest_pain_type': '4',
#   'num_major_vessels': '2',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '299',
#   'oldpeak_eq_st_depression': '0.9',
#   'sex': '1',
#   'age': '67',
#   'max_heart_rate_achieved': '125',
#   'exercise_induced_angina': '1'},
#  {'patient_id': 'wze8qm',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'normal',
#   'resting_blood_pressure': '135',
#   'chest_pain_type': '3',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '1',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '304',
#   'oldpeak_eq_st_depression': '0.0',
#   'sex': '0',
#   'age': '54',
#   'max_heart_rate_achieved': '170',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'w3933i',
#   'slope_of_peak_exercise_st_segment': '2',
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': '140',
#   'chest_pain_type': '4',
#   'num_major_vessels': '2',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '293',
#   'oldpeak_eq_st_depression': '1.2',
#   'sex': '1',
#   'age': '60',
#   'max_heart_rate_achieved': '170',
#   'exercise_induced_angina': '0'},
#  {'patient_id': '7uch9x',
#   'slope_of_peak_exercise_st_segment': '2',
#   'thal': 'normal',
#   'resting_blood_pressure': '108',
#   'chest_pain_type': '3',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '141',
#   'oldpeak_eq_st_depression': '0.6',
#   'sex': '0',
#   'age': '44',
#   'max_heart_rate_achieved': '175',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'dy5hxt',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': '118',
#   'chest_pain_type': '3',
#   'num_major_vessels': '1',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '277',
#   'oldpeak_eq_st_depression': '1.0',
#   'sex': '1',
#   'age': '68',
#   'max_heart_rate_achieved': '151',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'c0gkqc',
#   'slope_of_peak_exercise_st_segment': '2',
#   'thal': 'fixed_defect',
#   'resting_blood_pressure': '145',
#   'chest_pain_type': '4',
#   'num_major_vessels': '2',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '212',
#   'oldpeak_eq_st_depression': '2.0',
#   'sex': '1',
#   'age': '64',
#   'max_heart_rate_achieved': '132',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'z5g5p3',
#   'slope_of_peak_exercise_st_segment': '2',
#   'thal': 'normal',
#   'resting_blood_pressure': '160',
#   'chest_pain_type': '1',
#   'num_major_vessels': '1',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '1',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '234',
#   'oldpeak_eq_st_depression': '0.1',
#   'sex': '1',
#   'age': '69',
#   'max_heart_rate_achieved': '131',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'h3uzv8',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'normal',
#   'resting_blood_pressure': '155',
#   'chest_pain_type': '3',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '269',
#   'oldpeak_eq_st_depression': '0.8',
#   'sex': '0',
#   'age': '65',
#   'max_heart_rate_achieved': '148',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'bthqr4',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'normal',
#   'resting_blood_pressure': '150',
#   'chest_pain_type': '1',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '1',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '283',
#   'oldpeak_eq_st_depression': '1.0',
#   'sex': '0',
#   'age': '58',
#   'max_heart_rate_achieved': '162',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'rfj25e',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'normal',
#   'resting_blood_pressure': '140',
#   'chest_pain_type': '3',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '321',
#   'oldpeak_eq_st_depression': '0.0',
#   'sex': '1',
#   'age': '39',
#   'max_heart_rate_achieved': '182',
#   'exercise_induced_angina': '0'},
#  {'patient_id': '9f92et',
#   'slope_of_peak_exercise_st_segment': '2',
#   'thal': 'normal',
#   'resting_blood_pressure': '140',
#   'chest_pain_type': '2',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '294',
#   'oldpeak_eq_st_depression': '1.3',
#   'sex': '0',
#   'age': '56',
#   'max_heart_rate_achieved': '153',
#   'exercise_induced_angina': '0'},
#  {'patient_id': '24fopx',
#   'slope_of_peak_exercise_st_segment': '2',
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': '110',
#   'chest_pain_type': '4',
#   'num_major_vessels': '1',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '239',
#   'oldpeak_eq_st_depression': '1.2',
#   'sex': '1',
#   'age': '59',
#   'max_heart_rate_achieved': '142',
#   'exercise_induced_angina': '1'},
#  {'patient_id': 'ldr1mz',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'normal',
#   'resting_blood_pressure': '140',
#   'chest_pain_type': '3',
#   'num_major_vessels': '1',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '308',
#   'oldpeak_eq_st_depression': '1.5',
#   'sex': '0',
#   'age': '51',
#   'max_heart_rate_achieved': '142',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'wokyol',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': '140',
#   'chest_pain_type': '3',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '313',
#   'oldpeak_eq_st_depression': '0.2',
#   'sex': '0',
#   'age': '64',
#   'max_heart_rate_achieved': '133',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'p5orwa',
#   'slope_of_peak_exercise_st_segment': '2',
#   'thal': 'normal',
#   'resting_blood_pressure': '130',
#   'chest_pain_type': '4',
#   'num_major_vessels': '2',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '303',
#   'oldpeak_eq_st_depression': '2.0',
#   'sex': '0',
#   'age': '64',
#   'max_heart_rate_achieved': '122',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 's8dx1q',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': '150',
#   'chest_pain_type': '3',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '232',
#   'oldpeak_eq_st_depression': '1.6',
#   'sex': '1',
#   'age': '54',
#   'max_heart_rate_achieved': '165',
#   'exercise_induced_angina': '0'},
#  {'patient_id': '7kf275',
#   'slope_of_peak_exercise_st_segment': '2',
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': '160',
#   'chest_pain_type': '4',
#   'num_major_vessels': '1',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '289',
#   'oldpeak_eq_st_depression': '0.8',
#   'sex': '1',
#   'age': '55',
#   'max_heart_rate_achieved': '145',
#   'exercise_induced_angina': '1'},
#  {'patient_id': 'e68djo',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'normal',
#   'resting_blood_pressure': '125',
#   'chest_pain_type': '1',
#   'num_major_vessels': '1',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '213',
#   'oldpeak_eq_st_depression': '1.4',
#   'sex': '1',
#   'age': '51',
#   'max_heart_rate_achieved': '125',
#   'exercise_induced_angina': '1'},
#  {'patient_id': '3ze7pv',
#   'slope_of_peak_exercise_st_segment': '2',
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': '124',
#   'chest_pain_type': '4',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '274',
#   'oldpeak_eq_st_depression': '0.5',
# ...
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '216',
#   'oldpeak_eq_st_depression': '2.2',
#   'sex': '1',
#   'age': '58',
#   'max_heart_rate_achieved': '131',
#   'exercise_induced_angina': '1'},
#  {'patient_id': 'drdvf9',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'normal',
#   'resting_blood_pressure': '140',
#   'chest_pain_type': '2',
#   'num_major_vessels': '2',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '195',
#   'oldpeak_eq_st_depression': '0.0',
#   'sex': '0',
#   'age': '63',
#   'max_heart_rate_achieved': '179',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'z8yl4y',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': '140',
#   'chest_pain_type': '1',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '199',
#   'oldpeak_eq_st_depression': '1.4',
#   'sex': '1',
#   'age': '40',
#   'max_heart_rate_achieved': '178',
#   'exercise_induced_angina': '1'},
#  {'patient_id': 'mxabaz',
#   'slope_of_peak_exercise_st_segment': '2',
#   'thal': 'normal',
#   'resting_blood_pressure': '134',
#   'chest_pain_type': '1',
#   'num_major_vessels': '2',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '234',
#   'oldpeak_eq_st_depression': '2.6',
#   'sex': '1',
#   'age': '61',
#   'max_heart_rate_achieved': '145',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'cpqg4x',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'normal',
#   'resting_blood_pressure': '108',
#   'chest_pain_type': '3',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '243',
#   'oldpeak_eq_st_depression': '0.0',
#   'sex': '1',
#   'age': '47',
#   'max_heart_rate_achieved': '152',
#   'exercise_induced_angina': '0'},
#  {'patient_id': '8c36yw',
#   'slope_of_peak_exercise_st_segment': '2',
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': '128',
#   'chest_pain_type': '3',
#   'num_major_vessels': '1',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '229',
#   'oldpeak_eq_st_depression': '0.4',
#   'sex': '1',
#   'age': '57',
#   'max_heart_rate_achieved': '150',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'x4yp0f',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': '108',
#   'chest_pain_type': '2',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '309',
#   'oldpeak_eq_st_depression': '0.0',
#   'sex': '1',
#   'age': '54',
#   'max_heart_rate_achieved': '156',
#   'exercise_induced_angina': '0'},
#  {'patient_id': '9at0il',
#   'slope_of_peak_exercise_st_segment': '3',
#   'thal': 'normal',
#   'resting_blood_pressure': '125',
#   'chest_pain_type': '3',
#   'num_major_vessels': '1',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '273',
#   'oldpeak_eq_st_depression': '0.5',
#   'sex': '1',
#   'age': '54',
#   'max_heart_rate_achieved': '152',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'nfag5b',
#   'slope_of_peak_exercise_st_segment': '2',
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': '120',
#   'chest_pain_type': '4',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '198',
#   'oldpeak_eq_st_depression': '1.6',
#   'sex': '1',
#   'age': '35',
#   'max_heart_rate_achieved': '130',
#   'exercise_induced_angina': '1'},
#  {'patient_id': 'strmq8',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'normal',
#   'resting_blood_pressure': '112',
#   'chest_pain_type': '4',
#   'num_major_vessels': '1',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '290',
#   'oldpeak_eq_st_depression': '0.0',
#   'sex': '1',
#   'age': '44',
#   'max_heart_rate_achieved': '153',
#   'exercise_induced_angina': '0'},
#  {'patient_id': '43k3gx',
#   'slope_of_peak_exercise_st_segment': '2',
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': '130',
#   'chest_pain_type': '3',
#   'num_major_vessels': '1',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '263',
#   'oldpeak_eq_st_depression': '1.2',
#   'sex': '0',
#   'age': '62',
#   'max_heart_rate_achieved': '97',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'fz84ac',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'normal',
#   'resting_blood_pressure': '160',
#   'chest_pain_type': '1',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '273',
#   'oldpeak_eq_st_depression': '0.0',
#   'sex': '1',
#   'age': '59',
#   'max_heart_rate_achieved': '125',
#   'exercise_induced_angina': '0'},
#  {'patient_id': '02cipp',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'normal',
#   'resting_blood_pressure': '140',
#   'chest_pain_type': '1',
#   'num_major_vessels': '2',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '239',
#   'oldpeak_eq_st_depression': '1.8',
#   'sex': '0',
#   'age': '69',
#   'max_heart_rate_achieved': '151',
#   'exercise_induced_angina': '0'},
#  {'patient_id': '1ennzl',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'normal',
#   'resting_blood_pressure': '130',
#   'chest_pain_type': '3',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '275',
#   'oldpeak_eq_st_depression': '0.2',
#   'sex': '0',
#   'age': '48',
#   'max_heart_rate_achieved': '139',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'isq8yp',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'normal',
#   'resting_blood_pressure': '120',
#   'chest_pain_type': '3',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '226',
#   'oldpeak_eq_st_depression': '0.0',
#   'sex': '1',
#   'age': '44',
#   'max_heart_rate_achieved': '169',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'ewckbx',
#   'slope_of_peak_exercise_st_segment': '2',
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': '130',
#   'chest_pain_type': '4',
#   'num_major_vessels': '2',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '206',
#   'oldpeak_eq_st_depression': '2.4',
#   'sex': '1',
#   'age': '60',
#   'max_heart_rate_achieved': '132',
#   'exercise_induced_angina': '1'},
#  {'patient_id': 'dtljkq',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'normal',
#   'resting_blood_pressure': '130',
#   'chest_pain_type': '2',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '266',
#   'oldpeak_eq_st_depression': '0.6',
#   'sex': '1',
#   'age': '49',
#   'max_heart_rate_achieved': '171',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'a2kf1z',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': '117',
#   'chest_pain_type': '4',
#   'num_major_vessels': '2',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '1',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '230',
#   'oldpeak_eq_st_depression': '1.4',
#   'sex': '1',
#   'age': '60',
#   'max_heart_rate_achieved': '160',
#   'exercise_induced_angina': '1'},
#  {'patient_id': 'usnkhx',
#   'slope_of_peak_exercise_st_segment': '3',
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': '160',
#   'chest_pain_type': '4',
#   'num_major_vessels': '3',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '164',
#   'oldpeak_eq_st_depression': '6.2',
#   'sex': '0',
#   'age': '62',
#   'max_heart_rate_achieved': '145',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'hltlsl',
#   'slope_of_peak_exercise_st_segment': '2',
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': '142',
#   'chest_pain_type': '4',
#   'num_major_vessels': '3',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '309',
#   'oldpeak_eq_st_depression': '0.0',
#   'sex': '1',
#   'age': '45',
#   'max_heart_rate_achieved': '147',
#   'exercise_induced_angina': '1'},
#  {'patient_id': 'l0c19s',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': '142',
#   'chest_pain_type': '4',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '226',
#   'oldpeak_eq_st_depression': '0.0',
#   'sex': '1',
#   'age': '53',
#   'max_heart_rate_achieved': '111',
#   'exercise_induced_angina': '1'},
#  {'patient_id': 'lcexsf',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'normal',
#   'resting_blood_pressure': '152',
#   'chest_pain_type': '3',
#   'num_major_vessels': '1',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '277',
#   'oldpeak_eq_st_depression': '0.0',
#   'sex': '0',
#   'age': '67',
#   'max_heart_rate_achieved': '172',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'y3m2bd',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': '132',
#   'chest_pain_type': '4',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '207',
#   'oldpeak_eq_st_depression': '0.0',
#   'sex': '1',
#   'age': '57',
#   'max_heart_rate_achieved': '168',
#   'exercise_induced_angina': '1'},
#  {'patient_id': 'qcjf51',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': '120',
#   'chest_pain_type': '4',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '249',
#   'oldpeak_eq_st_depression': '0.8',
#   'sex': '1',
#   'age': '46',
#   'max_heart_rate_achieved': '144',
#   'exercise_induced_angina': '0'},
#  {'patient_id': '7zbya5',
#   'slope_of_peak_exercise_st_segment': '3',
#   'thal': 'fixed_defect',
#   'resting_blood_pressure': '145',
#   'chest_pain_type': '1',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '1',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '233',
#   'oldpeak_eq_st_depression': '2.3',
#   'sex': '1',
#   'age': '63',
#   'max_heart_rate_achieved': '150',
#   'exercise_induced_angina': '0'},
#  {'patient_id': '23gf0e',
#   'slope_of_peak_exercise_st_segment': '2',
#   'thal': 'normal',
#   'resting_blood_pressure': '110',
#   'chest_pain_type': '1',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '211',
#   'oldpeak_eq_st_depression': '1.8',
#   'sex': '1',
#   'age': '64',
#   'max_heart_rate_achieved': '144',
#   'exercise_induced_angina': '1'},
#  {'patient_id': 'qhz9ye',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': '150',
#   'chest_pain_type': '4',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '270',
#   'oldpeak_eq_st_depression': '0.8',
#   'sex': '1',
#   'age': '58',
#   'max_heart_rate_achieved': '111',
#   'exercise_induced_angina': '1'},
#  {'patient_id': 'u25507',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'normal',
#   'resting_blood_pressure': '112',
#   'chest_pain_type': '4',
#   'num_major_vessels': '1',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '212',
#   'oldpeak_eq_st_depression': '0.1',
#   'sex': '1',
#   'age': '66',
#   'max_heart_rate_achieved': '132',
#   'exercise_induced_angina': '1'},
#  {'patient_id': 'j9tw19',
#   'slope_of_peak_exercise_st_segment': '2',
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': '118',
#   'chest_pain_type': '4',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '219',
#   'oldpeak_eq_st_depression': '1.2',
#   'sex': '1',
#   'age': '39',
#   'max_heart_rate_achieved': '140',
#   'exercise_induced_angina': '0'},
#  {'patient_id': '5o32oi',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': '140',
#   'chest_pain_type': '4',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '299',
#   'oldpeak_eq_st_depression': '1.6',
#   'sex': '1',
#   'age': '51',
#   'max_heart_rate_achieved': '173',
#   'exercise_induced_angina': '1'},
#  {'patient_id': 'o63ri2',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'normal',
#   'resting_blood_pressure': '140',
#   'chest_pain_type': '4',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '239',
#   'oldpeak_eq_st_depression': '1.2',
#   'sex': '1',
#   'age': '54',
#   'max_heart_rate_achieved': '160',
#   'exercise_induced_angina': '0'},
#  {'patient_id': '5qfar3',
#   'slope_of_peak_exercise_st_segment': '2',
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': '125',
#   'chest_pain_type': '4',
#   'num_major_vessels': '2',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '1',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '254',
#   'oldpeak_eq_st_depression': '0.2',
#   'sex': '1',
#   'age': '67',
#   'max_heart_rate_achieved': '163',
#   'exercise_induced_angina': '0'},
#  {'patient_id': '2s2b1f',
#   'slope_of_peak_exercise_st_segment': '2',
#   'thal': 'normal',
#   'resting_blood_pressure': '180',
#   'chest_pain_type': '4',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '1',
#   'serum_cholesterol_mg_per_dl': '327',
#   'oldpeak_eq_st_depression': '3.4',
#   'sex': '0',
#   'age': '55',
#   'max_heart_rate_achieved': '117',
#   'exercise_induced_angina': '1'},
#  {'patient_id': 'nsd00i',
#   'slope_of_peak_exercise_st_segment': '2',
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': '125',
#   'chest_pain_type': '3',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '309',
#   'oldpeak_eq_st_depression': '1.8',
#   'sex': '1',
#   'age': '64',
#   'max_heart_rate_achieved': '131',
#   'exercise_induced_angina': '1'},
#  {'patient_id': '0xw93k',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'normal',
#   'resting_blood_pressure': '124',
#   'chest_pain_type': '3',
#   'num_major_vessels': '2',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '1',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '255',
#   'oldpeak_eq_st_depression': '0.0',
#   'sex': '1',
#   'age': '48',
#   'max_heart_rate_achieved': '175',
#   'exercise_induced_angina': '0'},
#  {'patient_id': '2nx10r',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'normal',
#   'resting_blood_pressure': '160',
#   'chest_pain_type': '3',
#   'num_major_vessels': '1',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '201',
#   'oldpeak_eq_st_depression': '0.0',
#   'sex': '0',
#   'age': '54',
#   'max_heart_rate_achieved': '163',
#   'exercise_induced_angina': '0'},
#  {'patient_id': '',
#   'slope_of_peak_exercise_st_segment': None,
#   'thal': None,
#   'resting_blood_pressure': None,
#   'chest_pain_type': None,
#   'num_major_vessels': None,
#   'fasting_blood_sugar_gt_120_mg_per_dl': None,
#   'resting_ekg_results': None,
#   'serum_cholesterol_mg_per_dl': None,
#   'oldpeak_eq_st_depression': None,
#   'sex': None,
#   'age': None,
#   'max_heart_rate_achieved': None,
#   'exercise_induced_angina': None}]

# %%
list
# Out:
# [{'patient_id': '0z64un',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'normal',
#   'resting_blood_pressure': '128',
#   'chest_pain_type': '2',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '308',
#   'oldpeak_eq_st_depression': '0.0',
#   'sex': '1',
#   'age': '45',
#   'max_heart_rate_achieved': '170',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'ryoo3j',
#   'slope_of_peak_exercise_st_segment': '2',
#   'thal': 'normal',
#   'resting_blood_pressure': '110',
#   'chest_pain_type': '3',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '214',
#   'oldpeak_eq_st_depression': '1.6',
#   'sex': '0',
#   'age': '54',
#   'max_heart_rate_achieved': '158',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'yt1s1x',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'normal',
#   'resting_blood_pressure': '125',
#   'chest_pain_type': '4',
#   'num_major_vessels': '3',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '304',
#   'oldpeak_eq_st_depression': '0.0',
#   'sex': '1',
#   'age': '77',
#   'max_heart_rate_achieved': '162',
#   'exercise_induced_angina': '1'},
#  {'patient_id': 'l2xjde',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': '152',
#   'chest_pain_type': '4',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '223',
#   'oldpeak_eq_st_depression': '0.0',
#   'sex': '1',
#   'age': '40',
#   'max_heart_rate_achieved': '181',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'oyt4ek',
#   'slope_of_peak_exercise_st_segment': '3',
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': '178',
#   'chest_pain_type': '1',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '270',
#   'oldpeak_eq_st_depression': '4.2',
#   'sex': '1',
#   'age': '59',
#   'max_heart_rate_achieved': '145',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'ldukkw',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'normal',
#   'resting_blood_pressure': '130',
#   'chest_pain_type': '3',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '180',
#   'oldpeak_eq_st_depression': '0.0',
#   'sex': '1',
#   'age': '42',
#   'max_heart_rate_achieved': '150',
#   'exercise_induced_angina': '0'},
#  {'patient_id': '2gbyh9',
#   'slope_of_peak_exercise_st_segment': '2',
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': '150',
#   'chest_pain_type': '4',
#   'num_major_vessels': '2',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '258',
#   'oldpeak_eq_st_depression': '2.6',
#   'sex': '0',
#   'age': '60',
#   'max_heart_rate_achieved': '157',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'daa9kp',
#   'slope_of_peak_exercise_st_segment': '2',
#   'thal': 'fixed_defect',
#   'resting_blood_pressure': '150',
#   'chest_pain_type': '4',
#   'num_major_vessels': '1',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '276',
#   'oldpeak_eq_st_depression': '0.6',
#   'sex': '1',
#   'age': '57',
#   'max_heart_rate_achieved': '112',
#   'exercise_induced_angina': '1'},
#  {'patient_id': '3nwy2n',
#   'slope_of_peak_exercise_st_segment': '3',
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': '170',
#   'chest_pain_type': '4',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '326',
#   'oldpeak_eq_st_depression': '3.4',
#   'sex': '1',
#   'age': '59',
#   'max_heart_rate_achieved': '140',
#   'exercise_induced_angina': '1'},
#  {'patient_id': '1r508r',
#   'slope_of_peak_exercise_st_segment': '2',
#   'thal': 'normal',
#   'resting_blood_pressure': '120',
#   'chest_pain_type': '3',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '219',
#   'oldpeak_eq_st_depression': '1.6',
#   'sex': '0',
#   'age': '50',
#   'max_heart_rate_achieved': '158',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'ldg4b9',
#   'slope_of_peak_exercise_st_segment': '2',
#   'thal': 'normal',
#   'resting_blood_pressure': '120',
#   'chest_pain_type': '4',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '302',
#   'oldpeak_eq_st_depression': '0.4',
#   'sex': '1',
#   'age': '66',
#   'max_heart_rate_achieved': '151',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'xc17yq',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'normal',
#   'resting_blood_pressure': '140',
#   'chest_pain_type': '4',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '226',
#   'oldpeak_eq_st_depression': '0.0',
#   'sex': '1',
#   'age': '42',
#   'max_heart_rate_achieved': '178',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'mpggsq',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'normal',
#   'resting_blood_pressure': '140',
#   'chest_pain_type': '3',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '335',
#   'oldpeak_eq_st_depression': '0.0',
#   'sex': '1',
#   'age': '64',
#   'max_heart_rate_achieved': '158',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'zlyac8',
#   'slope_of_peak_exercise_st_segment': '2',
#   'thal': 'normal',
#   'resting_blood_pressure': '138',
#   'chest_pain_type': '4',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '236',
#   'oldpeak_eq_st_depression': '0.2',
#   'sex': '0',
#   'age': '45',
#   'max_heart_rate_achieved': '152',
#   'exercise_induced_angina': '1'},
#  {'patient_id': 'f06u72',
#   'slope_of_peak_exercise_st_segment': '2',
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': '120',
#   'chest_pain_type': '1',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '231',
#   'oldpeak_eq_st_depression': '3.8',
#   'sex': '1',
#   'age': '38',
#   'max_heart_rate_achieved': '182',
#   'exercise_induced_angina': '1'},
#  {'patient_id': '2fv3rc',
#   'slope_of_peak_exercise_st_segment': '2',
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': '144',
#   'chest_pain_type': '4',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '200',
#   'oldpeak_eq_st_depression': '0.9',
#   'sex': '1',
#   'age': '50',
#   'max_heart_rate_achieved': '126',
#   'exercise_induced_angina': '1'},
#  {'patient_id': 'qyrkxn',
#   'slope_of_peak_exercise_st_segment': '2',
#   'thal': 'normal',
#   'resting_blood_pressure': '130',
#   'chest_pain_type': '2',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '234',
#   'oldpeak_eq_st_depression': '0.6',
#   'sex': '0',
#   'age': '45',
#   'max_heart_rate_achieved': '175',
#   'exercise_induced_angina': '0'},
#  {'patient_id': '237mql',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': '130',
#   'chest_pain_type': '4',
#   'num_major_vessels': '1',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '253',
#   'oldpeak_eq_st_depression': '1.4',
#   'sex': '1',
#   'age': '60',
#   'max_heart_rate_achieved': '144',
#   'exercise_induced_angina': '1'},
#  {'patient_id': 'mc750a',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'normal',
#   'resting_blood_pressure': '130',
#   'chest_pain_type': '2',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '204',
#   'oldpeak_eq_st_depression': '0.0',
#   'sex': '1',
#   'age': '29',
#   'max_heart_rate_achieved': '202',
#   'exercise_induced_angina': '0'},
#  {'patient_id': '30v796',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'normal',
#   'resting_blood_pressure': '136',
#   'chest_pain_type': '2',
#   'num_major_vessels': '2',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '1',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '319',
#   'oldpeak_eq_st_depression': '0.0',
#   'sex': '0',
#   'age': '58',
#   'max_heart_rate_achieved': '152',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'cvux3j',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'normal',
#   'resting_blood_pressure': '160',
#   'chest_pain_type': '2',
#   'num_major_vessels': '2',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '302',
#   'oldpeak_eq_st_depression': '0.4',
#   'sex': '0',
#   'age': '71',
#   'max_heart_rate_achieved': '162',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'k8899q',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': '108',
#   'chest_pain_type': '4',
#   'num_major_vessels': '3',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '1',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '233',
#   'oldpeak_eq_st_depression': '0.1',
#   'sex': '1',
#   'age': '52',
#   'max_heart_rate_achieved': '147',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'jhdvtb',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'normal',
#   'resting_blood_pressure': '106',
#   'chest_pain_type': '4',
#   'num_major_vessels': '2',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '223',
#   'oldpeak_eq_st_depression': '0.3',
#   'sex': '0',
#   'age': '67',
#   'max_heart_rate_achieved': '142',
#   'exercise_induced_angina': '0'},
#  {'patient_id': '5g9v0h',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'fixed_defect',
#   'resting_blood_pressure': '160',
#   'chest_pain_type': '4',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '228',
#   'oldpeak_eq_st_depression': '2.3',
#   'sex': '1',
#   'age': '66',
#   'max_heart_rate_achieved': '138',
#   'exercise_induced_angina': '0'},
#  {'patient_id': '83asqd',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'normal',
#   'resting_blood_pressure': '156',
#   'chest_pain_type': '2',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '245',
#   'oldpeak_eq_st_depression': '0.0',
#   'sex': '1',
#   'age': '70',
#   'max_heart_rate_achieved': '143',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'gla0im',
#   'slope_of_peak_exercise_st_segment': '2',
#   'thal': 'normal',
#   'resting_blood_pressure': '120',
#   'chest_pain_type': '3',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '211',
#   'oldpeak_eq_st_depression': '1.5',
#   'sex': '0',
#   'age': '68',
#   'max_heart_rate_achieved': '115',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'zzmfh7',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'normal',
#   'resting_blood_pressure': '128',
#   'chest_pain_type': '4',
#   'num_major_vessels': '1',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '303',
#   'oldpeak_eq_st_depression': '0.0',
#   'sex': '0',
#   'age': '57',
#   'max_heart_rate_achieved': '159',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'f4g1ay',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'normal',
#   'resting_blood_pressure': '128',
#   'chest_pain_type': '2',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '1',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '205',
#   'oldpeak_eq_st_depression': '0.0',
#   'sex': '1',
#   'age': '52',
#   'max_heart_rate_achieved': '184',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'lek9q9',
#   'slope_of_peak_exercise_st_segment': '2',
#   'thal': 'normal',
#   'resting_blood_pressure': '140',
#   'chest_pain_type': '3',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '185',
#   'oldpeak_eq_st_depression': '3.0',
#   'sex': '1',
#   'age': '60',
#   'max_heart_rate_achieved': '155',
#   'exercise_induced_angina': '0'},
#  {'patient_id': '8265rl',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'normal',
#   'resting_blood_pressure': '110',
#   'chest_pain_type': '3',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '175',
#   'oldpeak_eq_st_depression': '0.6',
#   'sex': '1',
#   'age': '51',
#   'max_heart_rate_achieved': '123',
#   'exercise_induced_angina': '0'},
#  {'patient_id': '6017a1',
#   'slope_of_peak_exercise_st_segment': '2',
#   'thal': 'normal',
#   'resting_blood_pressure': '130',
#   'chest_pain_type': '3',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '214',
#   'oldpeak_eq_st_depression': '2.0',
#   'sex': '1',
#   'age': '41',
#   'max_heart_rate_achieved': '168',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'z7xkou',
#   'slope_of_peak_exercise_st_segment': '2',
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': '150',
#   'chest_pain_type': '4',
#   'num_major_vessels': '3',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '225',
#   'oldpeak_eq_st_depression': '1.0',
#   'sex': '0',
#   'age': '65',
#   'max_heart_rate_achieved': '114',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'k7ef7h',
#   'slope_of_peak_exercise_st_segment': '3',
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': '140',
#   'chest_pain_type': '4',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '1',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '203',
#   'oldpeak_eq_st_depression': '3.1',
#   'sex': '1',
#   'age': '53',
#   'max_heart_rate_achieved': '155',
#   'exercise_induced_angina': '1'},
#  {'patient_id': '0n5fu0',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'normal',
#   'resting_blood_pressure': '180',
#   'chest_pain_type': '4',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '325',
#   'oldpeak_eq_st_depression': '0.0',
#   'sex': '0',
#   'age': '64',
#   'max_heart_rate_achieved': '154',
#   'exercise_induced_angina': '1'},
#  {'patient_id': '55xksg',
#   'slope_of_peak_exercise_st_segment': '2',
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': '112',
#   'chest_pain_type': '3',
#   'num_major_vessels': '1',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '230',
#   'oldpeak_eq_st_depression': '2.5',
#   'sex': '1',
#   'age': '58',
#   'max_heart_rate_achieved': '165',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'pjgqa3',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'normal',
#   'resting_blood_pressure': '122',
#   'chest_pain_type': '4',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '222',
#   'oldpeak_eq_st_depression': '0.0',
#   'sex': '1',
#   'age': '48',
#   'max_heart_rate_achieved': '186',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'xkdz7j',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': '150',
#   'chest_pain_type': '3',
#   'num_major_vessels': '1',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '1',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '126',
#   'oldpeak_eq_st_depression': '0.2',
#   'sex': '1',
#   'age': '57',
#   'max_heart_rate_achieved': '173',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'tpuevg',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'normal',
#   'resting_blood_pressure': '124',
#   'chest_pain_type': '4',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '209',
#   'oldpeak_eq_st_depression': '0.0',
#   'sex': '0',
#   'age': '62',
#   'max_heart_rate_achieved': '163',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'ascl42',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'normal',
#   'resting_blood_pressure': '120',
#   'chest_pain_type': '2',
#   'num_major_vessels': '1',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '269',
#   'oldpeak_eq_st_depression': '0.2',
#   'sex': '0',
#   'age': '74',
#   'max_heart_rate_achieved': '121',
#   'exercise_induced_angina': '1'},
#  {'patient_id': '1xwoe6',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': '128',
#   'chest_pain_type': '4',
#   'num_major_vessels': '1',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '255',
#   'oldpeak_eq_st_depression': '0.0',
#   'sex': '1',
#   'age': '52',
#   'max_heart_rate_achieved': '161',
#   'exercise_induced_angina': '1'},
#  {'patient_id': 'ty4ik8',
#   'slope_of_peak_exercise_st_segment': '2',
#   'thal': 'normal',
#   'resting_blood_pressure': '150',
#   'chest_pain_type': '3',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '1',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '243',
#   'oldpeak_eq_st_depression': '1.0',
#   'sex': '1',
#   'age': '61',
#   'max_heart_rate_achieved': '137',
#   'exercise_induced_angina': '1'},
#  {'patient_id': 'gx6yxl',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'normal',
#   'resting_blood_pressure': '135',
#   'chest_pain_type': '3',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '252',
#   'oldpeak_eq_st_depression': '0.0',
#   'sex': '0',
#   'age': '63',
#   'max_heart_rate_achieved': '172',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'hlmts5',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'normal',
#   'resting_blood_pressure': '110',
#   'chest_pain_type': '3',
#   'num_major_vessels': '1',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '1',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '265',
#   'oldpeak_eq_st_depression': '0.0',
#   'sex': '0',
#   'age': '71',
#   'max_heart_rate_achieved': '130',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'yx0q6k',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'normal',
#   'resting_blood_pressure': '140',
#   'chest_pain_type': '3',
#   'num_major_vessels': '1',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '1',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '417',
#   'oldpeak_eq_st_depression': '0.8',
#   'sex': '0',
#   'age': '65',
#   'max_heart_rate_achieved': '157',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'ep1o51',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'normal',
#   'resting_blood_pressure': '108',
#   'chest_pain_type': '3',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '267',
#   'oldpeak_eq_st_depression': '0.0',
#   'sex': '0',
#   'age': '54',
#   'max_heart_rate_achieved': '167',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'gj1e5z',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': '124',
#   'chest_pain_type': '2',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '261',
#   'oldpeak_eq_st_depression': '0.3',
#   'sex': '1',
#   'age': '57',
#   'max_heart_rate_achieved': '141',
#   'exercise_induced_angina': '0'},
#  {'patient_id': '6219kl',
#   'slope_of_peak_exercise_st_segment': '2',
#   'thal': 'normal',
#   'resting_blood_pressure': '125',
#   'chest_pain_type': '3',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '1',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '245',
#   'oldpeak_eq_st_depression': '2.4',
#   'sex': '1',
#   'age': '51',
#   'max_heart_rate_achieved': '166',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'rp9g6x',
#   'slope_of_peak_exercise_st_segment': '2',
#   'thal': 'normal',
#   'resting_blood_pressure': '112',
#   'chest_pain_type': '4',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '149',
#   'oldpeak_eq_st_depression': '1.6',
#   'sex': '0',
#   'age': '71',
#   'max_heart_rate_achieved': '125',
#   'exercise_induced_angina': '0'},
#  {'patient_id': '1aeaff',
#   'slope_of_peak_exercise_st_segment': '2',
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': '120',
#   'chest_pain_type': '2',
#   'num_major_vessels': '1',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '281',
#   'oldpeak_eq_st_depression': '1.4',
#   'sex': '1',
#   'age': '62',
#   'max_heart_rate_achieved': '103',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'y3prof',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'normal',
#   'resting_blood_pressure': '105',
#   'chest_pain_type': '2',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '204',
#   'oldpeak_eq_st_depression': '0.0',
#   'sex': '0',
#   'age': '46',
#   'max_heart_rate_achieved': '172',
#   'exercise_induced_angina': '0'},
#  {'patient_id': '3drd48',
#   'slope_of_peak_exercise_st_segment': '2',
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': '140',
#   'chest_pain_type': '4',
#   'num_major_vessels': '2',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '311',
#   'oldpeak_eq_st_depression': '1.8',
#   'sex': '1',
#   'age': '46',
#   'max_heart_rate_achieved': '120',
#   'exercise_induced_angina': '1'},
#  {'patient_id': 'ejo7p3',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'normal',
#   'resting_blood_pressure': '130',
#   'chest_pain_type': '3',
#   'num_major_vessels': '1',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '315',
#   'oldpeak_eq_st_depression': '1.9',
#   'sex': '1',
#   'age': '43',
#   'max_heart_rate_achieved': '162',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'r7y4i1',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': '130',
#   'chest_pain_type': '4',
#   'num_major_vessels': '3',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '1',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '330',
#   'oldpeak_eq_st_depression': '1.8',
#   'sex': '1',
#   'age': '63',
#   'max_heart_rate_achieved': '132',
#   'exercise_induced_angina': '1'},
#  {'patient_id': 'mznwxv',
#   'slope_of_peak_exercise_st_segment': '2',
#   'thal': 'fixed_defect',
#   'resting_blood_pressure': '130',
#   'chest_pain_type': '3',
#   'num_major_vessels': '1',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '1',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '256',
#   'oldpeak_eq_st_depression': '0.6',
#   'sex': '1',
#   'age': '56',
#   'max_heart_rate_achieved': '142',
#   'exercise_induced_angina': '1'},
#  {'patient_id': '27oevk',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'normal',
#   'resting_blood_pressure': '130',
#   'chest_pain_type': '4',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '330',
#   'oldpeak_eq_st_depression': '0.0',
#   'sex': '0',
#   'age': '61',
#   'max_heart_rate_achieved': '169',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'jwqi3k',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'normal',
#   'resting_blood_pressure': '130',
#   'chest_pain_type': '3',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '233',
#   'oldpeak_eq_st_depression': '0.4',
#   'sex': '1',
#   'age': '44',
#   'max_heart_rate_achieved': '179',
#   'exercise_induced_angina': '1'},
#  {'patient_id': '328lkl',
#   'slope_of_peak_exercise_st_segment': '2',
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': '110',
#   'chest_pain_type': '4',
#   'num_major_vessels': '1',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '239',
#   'oldpeak_eq_st_depression': '2.8',
#   'sex': '1',
#   'age': '54',
#   'max_heart_rate_achieved': '126',
#   'exercise_induced_angina': '1'},
#  {'patient_id': 'tlk9o8',
#   'slope_of_peak_exercise_st_segment': '2',
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': '120',
#   'chest_pain_type': '4',
#   'num_major_vessels': '2',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '267',
#   'oldpeak_eq_st_depression': '1.8',
#   'sex': '1',
#   'age': '62',
#   'max_heart_rate_achieved': '99',
#   'exercise_induced_angina': '1'},
#  {'patient_id': 'aq2vrq',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'normal',
#   'resting_blood_pressure': '120',
#   'chest_pain_type': '2',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '295',
#   'oldpeak_eq_st_depression': '0.0',
#   'sex': '1',
#   'age': '42',
#   'max_heart_rate_achieved': '162',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'ilogfb',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'normal',
#   'resting_blood_pressure': '110',
#   'chest_pain_type': '4',
#   'num_major_vessels': '1',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '197',
#   'oldpeak_eq_st_depression': '0.0',
#   'sex': '1',
#   'age': '44',
#   'max_heart_rate_achieved': '177',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'rv6siv',
#   'slope_of_peak_exercise_st_segment': '2',
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': '115',
#   'chest_pain_type': '3',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '564',
#   'oldpeak_eq_st_depression': '1.6',
#   'sex': '0',
#   'age': '67',
#   'max_heart_rate_achieved': '160',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'm2a4i9',
#   'slope_of_peak_exercise_st_segment': '2',
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': '130',
#   'chest_pain_type': '4',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '305',
#   'oldpeak_eq_st_depression': '1.2',
#   'sex': '0',
#   'age': '51',
#   'max_heart_rate_achieved': '142',
#   'exercise_induced_angina': '1'},
#  {'patient_id': 'pwigd8',
#   'slope_of_peak_exercise_st_segment': '3',
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': '130',
#   'chest_pain_type': '4',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '1',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '283',
#   'oldpeak_eq_st_depression': '1.6',
#   'sex': '1',
#   'age': '56',
#   'max_heart_rate_achieved': '103',
#   'exercise_induced_angina': '1'},
#  {'patient_id': 'qwapdq',
#   'slope_of_peak_exercise_st_segment': '2',
#   'thal': 'normal',
#   'resting_blood_pressure': '112',
#   'chest_pain_type': '2',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '160',
#   'oldpeak_eq_st_depression': '0.0',
#   'sex': '0',
#   'age': '45',
#   'max_heart_rate_achieved': '138',
#   'exercise_induced_angina': '0'},
#  {'patient_id': '4sd1xn',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'normal',
#   'resting_blood_pressure': '110',
#   'chest_pain_type': '4',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '254',
#   'oldpeak_eq_st_depression': '0.0',
#   'sex': '0',
#   'age': '50',
#   'max_heart_rate_achieved': '159',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'nck22c',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': '126',
#   'chest_pain_type': '4',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '282',
#   'oldpeak_eq_st_depression': '0.0',
#   'sex': '1',
#   'age': '35',
#   'max_heart_rate_achieved': '156',
#   'exercise_induced_angina': '1'},
#  {'patient_id': 'm6zksp',
#   'slope_of_peak_exercise_st_segment': '2',
#   'thal': 'normal',
#   'resting_blood_pressure': '130',
#   'chest_pain_type': '4',
#   'num_major_vessels': '3',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '322',
#   'oldpeak_eq_st_depression': '2.4',
#   'sex': '1',
#   'age': '70',
#   'max_heart_rate_achieved': '109',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'f70grj',
#   'slope_of_peak_exercise_st_segment': '2',
#   'thal': 'normal',
#   'resting_blood_pressure': '115',
#   'chest_pain_type': '4',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '303',
#   'oldpeak_eq_st_depression': '1.2',
#   'sex': '1',
#   'age': '43',
#   'max_heart_rate_achieved': '181',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'k1art8',
#   'slope_of_peak_exercise_st_segment': '2',
#   'thal': 'normal',
#   'resting_blood_pressure': '135',
#   'chest_pain_type': '2',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '250',
#   'oldpeak_eq_st_depression': '1.4',
#   'sex': '0',
#   'age': '55',
#   'max_heart_rate_achieved': '161',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'mcwqgs',
#   'slope_of_peak_exercise_st_segment': '2',
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': '120',
#   'chest_pain_type': '3',
#   'num_major_vessels': '3',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '188',
#   'oldpeak_eq_st_depression': '2.0',
#   'sex': '1',
#   'age': '49',
#   'max_heart_rate_achieved': '139',
#   'exercise_induced_angina': '0'},
#  {'patient_id': '3jsjqk',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'normal',
#   'resting_blood_pressure': '120',
#   'chest_pain_type': '2',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '220',
#   'oldpeak_eq_st_depression': '0.0',
#   'sex': '1',
#   'age': '44',
#   'max_heart_rate_achieved': '170',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'ik7hfs',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'normal',
#   'resting_blood_pressure': '112',
#   'chest_pain_type': '4',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '204',
#   'oldpeak_eq_st_depression': '0.1',
#   'sex': '1',
#   'age': '47',
#   'max_heart_rate_achieved': '143',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'qwj1yf',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': '172',
#   'chest_pain_type': '3',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '1',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '199',
#   'oldpeak_eq_st_depression': '0.5',
#   'sex': '1',
#   'age': '52',
#   'max_heart_rate_achieved': '162',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'qvhk9e',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'normal',
#   'resting_blood_pressure': '120',
#   'chest_pain_type': '3',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '215',
#   'oldpeak_eq_st_depression': '0.0',
#   'sex': '0',
#   'age': '37',
#   'max_heart_rate_achieved': '170',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'igwnqo',
#   'slope_of_peak_exercise_st_segment': '2',
#   'thal': 'fixed_defect',
#   'resting_blood_pressure': '126',
#   'chest_pain_type': '3',
#   'num_major_vessels': '1',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '1',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '218',
#   'oldpeak_eq_st_depression': '2.2',
#   'sex': '1',
#   'age': '59',
#   'max_heart_rate_achieved': '134',
#   'exercise_induced_angina': '0'},
#  {'patient_id': '4v0q7o',
#   'slope_of_peak_exercise_st_segment': '2',
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': '178',
#   'chest_pain_type': '4',
#   'num_major_vessels': '2',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '1',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '228',
#   'oldpeak_eq_st_depression': '1.0',
#   'sex': '0',
#   'age': '66',
#   'max_heart_rate_achieved': '165',
#   'exercise_induced_angina': '1'},
#  {'patient_id': 'hh2awp',
#   'slope_of_peak_exercise_st_segment': '2',
#   'thal': 'normal',
#   'resting_blood_pressure': '136',
#   'chest_pain_type': '3',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '196',
#   'oldpeak_eq_st_depression': '0.1',
#   'sex': '0',
#   'age': '52',
#   'max_heart_rate_achieved': '169',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'vfjppl',
#   'slope_of_peak_exercise_st_segment': '2',
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': '124',
#   'chest_pain_type': '4',
#   'num_major_vessels': '1',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '266',
#   'oldpeak_eq_st_depression': '2.2',
#   'sex': '1',
#   'age': '54',
#   'max_heart_rate_achieved': '109',
#   'exercise_induced_angina': '1'},
#  {'patient_id': '6lu42b',
#   'slope_of_peak_exercise_st_segment': '2',
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': '145',
#   'chest_pain_type': '4',
#   'num_major_vessels': '2',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '282',
#   'oldpeak_eq_st_depression': '2.8',
#   'sex': '1',
#   'age': '60',
#   'max_heart_rate_achieved': '142',
#   'exercise_induced_angina': '1'},
#  {'patient_id': 'shiro4',
#   'slope_of_peak_exercise_st_segment': '2',
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': '130',
#   'chest_pain_type': '4',
#   'num_major_vessels': '1',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '254',
#   'oldpeak_eq_st_depression': '1.4',
#   'sex': '1',
#   'age': '63',
#   'max_heart_rate_achieved': '147',
#   'exercise_induced_angina': '0'},
#  {'patient_id': '3wl3z4',
#   'slope_of_peak_exercise_st_segment': '3',
#   'thal': 'normal',
#   'resting_blood_pressure': '130',
#   'chest_pain_type': '3',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '1',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '197',
#   'oldpeak_eq_st_depression': '1.2',
#   'sex': '1',
#   'age': '53',
#   'max_heart_rate_achieved': '152',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'ebioez',
#   'slope_of_peak_exercise_st_segment': '2',
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': '120',
#   'chest_pain_type': '4',
#   'num_major_vessels': '1',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '188',
#   'oldpeak_eq_st_depression': '1.4',
#   'sex': '1',
#   'age': '54',
#   'max_heart_rate_achieved': '113',
#   'exercise_induced_angina': '0'},
#  {'patient_id': '37c0vm',
#   'slope_of_peak_exercise_st_segment': '3',
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': '110',
#   'chest_pain_type': '2',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '229',
#   'oldpeak_eq_st_depression': '1.0',
#   'sex': '1',
#   'age': '48',
#   'max_heart_rate_achieved': '168',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'v52zcs',
#   'slope_of_peak_exercise_st_segment': '2',
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': '128',
#   'chest_pain_type': '4',
#   'num_major_vessels': '2',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '259',
#   'oldpeak_eq_st_depression': '3.0',
#   'sex': '1',
#   'age': '58',
#   'max_heart_rate_achieved': '130',
#   'exercise_induced_angina': '1'},
#  {'patient_id': '6nkcaw',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'normal',
#   'resting_blood_pressure': '130',
#   'chest_pain_type': '3',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '256',
#   'oldpeak_eq_st_depression': '0.5',
#   'sex': '0',
#   'age': '51',
#   'max_heart_rate_achieved': '149',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'hfp05i',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'normal',
#   'resting_blood_pressure': '118',
#   'chest_pain_type': '3',
#   'num_major_vessels': '3',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '149',
#   'oldpeak_eq_st_depression': '0.8',
#   'sex': '1',
#   'age': '49',
#   'max_heart_rate_achieved': '126',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'grfxwd',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'normal',
#   'resting_blood_pressure': '112',
#   'chest_pain_type': '3',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '268',
#   'oldpeak_eq_st_depression': '0.0',
#   'sex': '0',
#   'age': '41',
#   'max_heart_rate_achieved': '172',
#   'exercise_induced_angina': '1'},
#  {'patient_id': 'bvcxah',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': '140',
#   'chest_pain_type': '4',
#   'num_major_vessels': '1',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '177',
#   'oldpeak_eq_st_depression': '0.0',
#   'sex': '1',
#   'age': '59',
#   'max_heart_rate_achieved': '162',
#   'exercise_induced_angina': '1'},
#  {'patient_id': 'i49srr',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'normal',
#   'resting_blood_pressure': '150',
#   'chest_pain_type': '3',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '168',
#   'oldpeak_eq_st_depression': '1.6',
#   'sex': '1',
#   'age': '57',
#   'max_heart_rate_achieved': '174',
#   'exercise_induced_angina': '0'},
#  {'patient_id': '93dbhq',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'normal',
#   'resting_blood_pressure': '130',
#   'chest_pain_type': '2',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '262',
#   'oldpeak_eq_st_depression': '0.0',
#   'sex': '1',
#   'age': '55',
#   'max_heart_rate_achieved': '155',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'jscmp8',
#   'slope_of_peak_exercise_st_segment': '2',
#   'thal': 'normal',
#   'resting_blood_pressure': '134',
#   'chest_pain_type': '2',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '271',
#   'oldpeak_eq_st_depression': '0.0',
#   'sex': '0',
#   'age': '49',
#   'max_heart_rate_achieved': '162',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'zaytyf',
#   'slope_of_peak_exercise_st_segment': '2',
#   'thal': 'normal',
#   'resting_blood_pressure': '100',
#   'chest_pain_type': '4',
#   'num_major_vessels': '2',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '299',
#   'oldpeak_eq_st_depression': '0.9',
#   'sex': '1',
#   'age': '67',
#   'max_heart_rate_achieved': '125',
#   'exercise_induced_angina': '1'},
#  {'patient_id': 'wze8qm',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'normal',
#   'resting_blood_pressure': '135',
#   'chest_pain_type': '3',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '1',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '304',
#   'oldpeak_eq_st_depression': '0.0',
#   'sex': '0',
#   'age': '54',
#   'max_heart_rate_achieved': '170',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'w3933i',
#   'slope_of_peak_exercise_st_segment': '2',
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': '140',
#   'chest_pain_type': '4',
#   'num_major_vessels': '2',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '293',
#   'oldpeak_eq_st_depression': '1.2',
#   'sex': '1',
#   'age': '60',
#   'max_heart_rate_achieved': '170',
#   'exercise_induced_angina': '0'},
#  {'patient_id': '7uch9x',
#   'slope_of_peak_exercise_st_segment': '2',
#   'thal': 'normal',
#   'resting_blood_pressure': '108',
#   'chest_pain_type': '3',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '141',
#   'oldpeak_eq_st_depression': '0.6',
#   'sex': '0',
#   'age': '44',
#   'max_heart_rate_achieved': '175',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'dy5hxt',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': '118',
#   'chest_pain_type': '3',
#   'num_major_vessels': '1',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '277',
#   'oldpeak_eq_st_depression': '1.0',
#   'sex': '1',
#   'age': '68',
#   'max_heart_rate_achieved': '151',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'c0gkqc',
#   'slope_of_peak_exercise_st_segment': '2',
#   'thal': 'fixed_defect',
#   'resting_blood_pressure': '145',
#   'chest_pain_type': '4',
#   'num_major_vessels': '2',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '212',
#   'oldpeak_eq_st_depression': '2.0',
#   'sex': '1',
#   'age': '64',
#   'max_heart_rate_achieved': '132',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'z5g5p3',
#   'slope_of_peak_exercise_st_segment': '2',
#   'thal': 'normal',
#   'resting_blood_pressure': '160',
#   'chest_pain_type': '1',
#   'num_major_vessels': '1',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '1',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '234',
#   'oldpeak_eq_st_depression': '0.1',
#   'sex': '1',
#   'age': '69',
#   'max_heart_rate_achieved': '131',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'h3uzv8',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'normal',
#   'resting_blood_pressure': '155',
#   'chest_pain_type': '3',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '269',
#   'oldpeak_eq_st_depression': '0.8',
#   'sex': '0',
#   'age': '65',
#   'max_heart_rate_achieved': '148',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'bthqr4',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'normal',
#   'resting_blood_pressure': '150',
#   'chest_pain_type': '1',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '1',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '283',
#   'oldpeak_eq_st_depression': '1.0',
#   'sex': '0',
#   'age': '58',
#   'max_heart_rate_achieved': '162',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'rfj25e',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'normal',
#   'resting_blood_pressure': '140',
#   'chest_pain_type': '3',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '321',
#   'oldpeak_eq_st_depression': '0.0',
#   'sex': '1',
#   'age': '39',
#   'max_heart_rate_achieved': '182',
#   'exercise_induced_angina': '0'},
#  {'patient_id': '9f92et',
#   'slope_of_peak_exercise_st_segment': '2',
#   'thal': 'normal',
#   'resting_blood_pressure': '140',
#   'chest_pain_type': '2',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '294',
#   'oldpeak_eq_st_depression': '1.3',
#   'sex': '0',
#   'age': '56',
#   'max_heart_rate_achieved': '153',
#   'exercise_induced_angina': '0'},
#  {'patient_id': '24fopx',
#   'slope_of_peak_exercise_st_segment': '2',
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': '110',
#   'chest_pain_type': '4',
#   'num_major_vessels': '1',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '239',
#   'oldpeak_eq_st_depression': '1.2',
#   'sex': '1',
#   'age': '59',
#   'max_heart_rate_achieved': '142',
#   'exercise_induced_angina': '1'},
#  {'patient_id': 'ldr1mz',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'normal',
#   'resting_blood_pressure': '140',
#   'chest_pain_type': '3',
#   'num_major_vessels': '1',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '308',
#   'oldpeak_eq_st_depression': '1.5',
#   'sex': '0',
#   'age': '51',
#   'max_heart_rate_achieved': '142',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'wokyol',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': '140',
#   'chest_pain_type': '3',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '313',
#   'oldpeak_eq_st_depression': '0.2',
#   'sex': '0',
#   'age': '64',
#   'max_heart_rate_achieved': '133',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'p5orwa',
#   'slope_of_peak_exercise_st_segment': '2',
#   'thal': 'normal',
#   'resting_blood_pressure': '130',
#   'chest_pain_type': '4',
#   'num_major_vessels': '2',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '303',
#   'oldpeak_eq_st_depression': '2.0',
#   'sex': '0',
#   'age': '64',
#   'max_heart_rate_achieved': '122',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 's8dx1q',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': '150',
#   'chest_pain_type': '3',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '232',
#   'oldpeak_eq_st_depression': '1.6',
#   'sex': '1',
#   'age': '54',
#   'max_heart_rate_achieved': '165',
#   'exercise_induced_angina': '0'},
#  {'patient_id': '7kf275',
#   'slope_of_peak_exercise_st_segment': '2',
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': '160',
#   'chest_pain_type': '4',
#   'num_major_vessels': '1',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '289',
#   'oldpeak_eq_st_depression': '0.8',
#   'sex': '1',
#   'age': '55',
#   'max_heart_rate_achieved': '145',
#   'exercise_induced_angina': '1'},
#  {'patient_id': 'e68djo',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'normal',
#   'resting_blood_pressure': '125',
#   'chest_pain_type': '1',
#   'num_major_vessels': '1',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '213',
#   'oldpeak_eq_st_depression': '1.4',
#   'sex': '1',
#   'age': '51',
#   'max_heart_rate_achieved': '125',
#   'exercise_induced_angina': '1'},
#  {'patient_id': '3ze7pv',
#   'slope_of_peak_exercise_st_segment': '2',
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': '124',
#   'chest_pain_type': '4',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '274',
#   'oldpeak_eq_st_depression': '0.5',
# ...
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '216',
#   'oldpeak_eq_st_depression': '2.2',
#   'sex': '1',
#   'age': '58',
#   'max_heart_rate_achieved': '131',
#   'exercise_induced_angina': '1'},
#  {'patient_id': 'drdvf9',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'normal',
#   'resting_blood_pressure': '140',
#   'chest_pain_type': '2',
#   'num_major_vessels': '2',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '195',
#   'oldpeak_eq_st_depression': '0.0',
#   'sex': '0',
#   'age': '63',
#   'max_heart_rate_achieved': '179',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'z8yl4y',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': '140',
#   'chest_pain_type': '1',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '199',
#   'oldpeak_eq_st_depression': '1.4',
#   'sex': '1',
#   'age': '40',
#   'max_heart_rate_achieved': '178',
#   'exercise_induced_angina': '1'},
#  {'patient_id': 'mxabaz',
#   'slope_of_peak_exercise_st_segment': '2',
#   'thal': 'normal',
#   'resting_blood_pressure': '134',
#   'chest_pain_type': '1',
#   'num_major_vessels': '2',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '234',
#   'oldpeak_eq_st_depression': '2.6',
#   'sex': '1',
#   'age': '61',
#   'max_heart_rate_achieved': '145',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'cpqg4x',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'normal',
#   'resting_blood_pressure': '108',
#   'chest_pain_type': '3',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '243',
#   'oldpeak_eq_st_depression': '0.0',
#   'sex': '1',
#   'age': '47',
#   'max_heart_rate_achieved': '152',
#   'exercise_induced_angina': '0'},
#  {'patient_id': '8c36yw',
#   'slope_of_peak_exercise_st_segment': '2',
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': '128',
#   'chest_pain_type': '3',
#   'num_major_vessels': '1',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '229',
#   'oldpeak_eq_st_depression': '0.4',
#   'sex': '1',
#   'age': '57',
#   'max_heart_rate_achieved': '150',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'x4yp0f',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': '108',
#   'chest_pain_type': '2',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '309',
#   'oldpeak_eq_st_depression': '0.0',
#   'sex': '1',
#   'age': '54',
#   'max_heart_rate_achieved': '156',
#   'exercise_induced_angina': '0'},
#  {'patient_id': '9at0il',
#   'slope_of_peak_exercise_st_segment': '3',
#   'thal': 'normal',
#   'resting_blood_pressure': '125',
#   'chest_pain_type': '3',
#   'num_major_vessels': '1',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '273',
#   'oldpeak_eq_st_depression': '0.5',
#   'sex': '1',
#   'age': '54',
#   'max_heart_rate_achieved': '152',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'nfag5b',
#   'slope_of_peak_exercise_st_segment': '2',
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': '120',
#   'chest_pain_type': '4',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '198',
#   'oldpeak_eq_st_depression': '1.6',
#   'sex': '1',
#   'age': '35',
#   'max_heart_rate_achieved': '130',
#   'exercise_induced_angina': '1'},
#  {'patient_id': 'strmq8',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'normal',
#   'resting_blood_pressure': '112',
#   'chest_pain_type': '4',
#   'num_major_vessels': '1',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '290',
#   'oldpeak_eq_st_depression': '0.0',
#   'sex': '1',
#   'age': '44',
#   'max_heart_rate_achieved': '153',
#   'exercise_induced_angina': '0'},
#  {'patient_id': '43k3gx',
#   'slope_of_peak_exercise_st_segment': '2',
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': '130',
#   'chest_pain_type': '3',
#   'num_major_vessels': '1',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '263',
#   'oldpeak_eq_st_depression': '1.2',
#   'sex': '0',
#   'age': '62',
#   'max_heart_rate_achieved': '97',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'fz84ac',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'normal',
#   'resting_blood_pressure': '160',
#   'chest_pain_type': '1',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '273',
#   'oldpeak_eq_st_depression': '0.0',
#   'sex': '1',
#   'age': '59',
#   'max_heart_rate_achieved': '125',
#   'exercise_induced_angina': '0'},
#  {'patient_id': '02cipp',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'normal',
#   'resting_blood_pressure': '140',
#   'chest_pain_type': '1',
#   'num_major_vessels': '2',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '239',
#   'oldpeak_eq_st_depression': '1.8',
#   'sex': '0',
#   'age': '69',
#   'max_heart_rate_achieved': '151',
#   'exercise_induced_angina': '0'},
#  {'patient_id': '1ennzl',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'normal',
#   'resting_blood_pressure': '130',
#   'chest_pain_type': '3',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '275',
#   'oldpeak_eq_st_depression': '0.2',
#   'sex': '0',
#   'age': '48',
#   'max_heart_rate_achieved': '139',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'isq8yp',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'normal',
#   'resting_blood_pressure': '120',
#   'chest_pain_type': '3',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '226',
#   'oldpeak_eq_st_depression': '0.0',
#   'sex': '1',
#   'age': '44',
#   'max_heart_rate_achieved': '169',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'ewckbx',
#   'slope_of_peak_exercise_st_segment': '2',
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': '130',
#   'chest_pain_type': '4',
#   'num_major_vessels': '2',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '206',
#   'oldpeak_eq_st_depression': '2.4',
#   'sex': '1',
#   'age': '60',
#   'max_heart_rate_achieved': '132',
#   'exercise_induced_angina': '1'},
#  {'patient_id': 'dtljkq',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'normal',
#   'resting_blood_pressure': '130',
#   'chest_pain_type': '2',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '266',
#   'oldpeak_eq_st_depression': '0.6',
#   'sex': '1',
#   'age': '49',
#   'max_heart_rate_achieved': '171',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'a2kf1z',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': '117',
#   'chest_pain_type': '4',
#   'num_major_vessels': '2',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '1',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '230',
#   'oldpeak_eq_st_depression': '1.4',
#   'sex': '1',
#   'age': '60',
#   'max_heart_rate_achieved': '160',
#   'exercise_induced_angina': '1'},
#  {'patient_id': 'usnkhx',
#   'slope_of_peak_exercise_st_segment': '3',
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': '160',
#   'chest_pain_type': '4',
#   'num_major_vessels': '3',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '164',
#   'oldpeak_eq_st_depression': '6.2',
#   'sex': '0',
#   'age': '62',
#   'max_heart_rate_achieved': '145',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'hltlsl',
#   'slope_of_peak_exercise_st_segment': '2',
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': '142',
#   'chest_pain_type': '4',
#   'num_major_vessels': '3',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '309',
#   'oldpeak_eq_st_depression': '0.0',
#   'sex': '1',
#   'age': '45',
#   'max_heart_rate_achieved': '147',
#   'exercise_induced_angina': '1'},
#  {'patient_id': 'l0c19s',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': '142',
#   'chest_pain_type': '4',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '226',
#   'oldpeak_eq_st_depression': '0.0',
#   'sex': '1',
#   'age': '53',
#   'max_heart_rate_achieved': '111',
#   'exercise_induced_angina': '1'},
#  {'patient_id': 'lcexsf',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'normal',
#   'resting_blood_pressure': '152',
#   'chest_pain_type': '3',
#   'num_major_vessels': '1',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '277',
#   'oldpeak_eq_st_depression': '0.0',
#   'sex': '0',
#   'age': '67',
#   'max_heart_rate_achieved': '172',
#   'exercise_induced_angina': '0'},
#  {'patient_id': 'y3m2bd',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': '132',
#   'chest_pain_type': '4',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '207',
#   'oldpeak_eq_st_depression': '0.0',
#   'sex': '1',
#   'age': '57',
#   'max_heart_rate_achieved': '168',
#   'exercise_induced_angina': '1'},
#  {'patient_id': 'qcjf51',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': '120',
#   'chest_pain_type': '4',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '249',
#   'oldpeak_eq_st_depression': '0.8',
#   'sex': '1',
#   'age': '46',
#   'max_heart_rate_achieved': '144',
#   'exercise_induced_angina': '0'},
#  {'patient_id': '7zbya5',
#   'slope_of_peak_exercise_st_segment': '3',
#   'thal': 'fixed_defect',
#   'resting_blood_pressure': '145',
#   'chest_pain_type': '1',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '1',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '233',
#   'oldpeak_eq_st_depression': '2.3',
#   'sex': '1',
#   'age': '63',
#   'max_heart_rate_achieved': '150',
#   'exercise_induced_angina': '0'},
#  {'patient_id': '23gf0e',
#   'slope_of_peak_exercise_st_segment': '2',
#   'thal': 'normal',
#   'resting_blood_pressure': '110',
#   'chest_pain_type': '1',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '211',
#   'oldpeak_eq_st_depression': '1.8',
#   'sex': '1',
#   'age': '64',
#   'max_heart_rate_achieved': '144',
#   'exercise_induced_angina': '1'},
#  {'patient_id': 'qhz9ye',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': '150',
#   'chest_pain_type': '4',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '270',
#   'oldpeak_eq_st_depression': '0.8',
#   'sex': '1',
#   'age': '58',
#   'max_heart_rate_achieved': '111',
#   'exercise_induced_angina': '1'},
#  {'patient_id': 'u25507',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'normal',
#   'resting_blood_pressure': '112',
#   'chest_pain_type': '4',
#   'num_major_vessels': '1',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '2',
#   'serum_cholesterol_mg_per_dl': '212',
#   'oldpeak_eq_st_depression': '0.1',
#   'sex': '1',
#   'age': '66',
#   'max_heart_rate_achieved': '132',
#   'exercise_induced_angina': '1'},
#  {'patient_id': 'j9tw19',
#   'slope_of_peak_exercise_st_segment': '2',
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': '118',
#   'chest_pain_type': '4',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '219',
#   'oldpeak_eq_st_depression': '1.2',
#   'sex': '1',
#   'age': '39',
#   'max_heart_rate_achieved': '140',
#   'exercise_induced_angina': '0'},
#  {'patient_id': '5o32oi',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': '140',
#   'chest_pain_type': '4',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '299',
#   'oldpeak_eq_st_depression': '1.6',
#   'sex': '1',
#   'age': '51',
#   'max_heart_rate_achieved': '173',
#   'exercise_induced_angina': '1'},
#  {'patient_id': 'o63ri2',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'normal',
#   'resting_blood_pressure': '140',
#   'chest_pain_type': '4',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '239',
#   'oldpeak_eq_st_depression': '1.2',
#   'sex': '1',
#   'age': '54',
#   'max_heart_rate_achieved': '160',
#   'exercise_induced_angina': '0'},
#  {'patient_id': '5qfar3',
#   'slope_of_peak_exercise_st_segment': '2',
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': '125',
#   'chest_pain_type': '4',
#   'num_major_vessels': '2',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '1',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '254',
#   'oldpeak_eq_st_depression': '0.2',
#   'sex': '1',
#   'age': '67',
#   'max_heart_rate_achieved': '163',
#   'exercise_induced_angina': '0'},
#  {'patient_id': '2s2b1f',
#   'slope_of_peak_exercise_st_segment': '2',
#   'thal': 'normal',
#   'resting_blood_pressure': '180',
#   'chest_pain_type': '4',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '1',
#   'serum_cholesterol_mg_per_dl': '327',
#   'oldpeak_eq_st_depression': '3.4',
#   'sex': '0',
#   'age': '55',
#   'max_heart_rate_achieved': '117',
#   'exercise_induced_angina': '1'},
#  {'patient_id': 'nsd00i',
#   'slope_of_peak_exercise_st_segment': '2',
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': '125',
#   'chest_pain_type': '3',
#   'num_major_vessels': '0',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '309',
#   'oldpeak_eq_st_depression': '1.8',
#   'sex': '1',
#   'age': '64',
#   'max_heart_rate_achieved': '131',
#   'exercise_induced_angina': '1'},
#  {'patient_id': '0xw93k',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'normal',
#   'resting_blood_pressure': '124',
#   'chest_pain_type': '3',
#   'num_major_vessels': '2',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '1',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '255',
#   'oldpeak_eq_st_depression': '0.0',
#   'sex': '1',
#   'age': '48',
#   'max_heart_rate_achieved': '175',
#   'exercise_induced_angina': '0'},
#  {'patient_id': '2nx10r',
#   'slope_of_peak_exercise_st_segment': '1',
#   'thal': 'normal',
#   'resting_blood_pressure': '160',
#   'chest_pain_type': '3',
#   'num_major_vessels': '1',
#   'fasting_blood_sugar_gt_120_mg_per_dl': '0',
#   'resting_ekg_results': '0',
#   'serum_cholesterol_mg_per_dl': '201',
#   'oldpeak_eq_st_depression': '0.0',
#   'sex': '0',
#   'age': '54',
#   'max_heart_rate_achieved': '163',
#   'exercise_induced_angina': '0'},
#  {'patient_id': '',
#   'slope_of_peak_exercise_st_segment': None,
#   'thal': None,
#   'resting_blood_pressure': None,
#   'chest_pain_type': None,
#   'num_major_vessels': None,
#   'fasting_blood_sugar_gt_120_mg_per_dl': None,
#   'resting_ekg_results': None,
#   'serum_cholesterol_mg_per_dl': None,
#   'oldpeak_eq_st_depression': None,
#   'sex': None,
#   'age': None,
#   'max_heart_rate_achieved': None,
#   'exercise_induced_angina': None}]

# %%
d
# Out:
# {0: {'patient_id': '0z64un',
#   'slope_of_peak_exercise_st_segment': 1,
#   'thal': 'normal',
#   'resting_blood_pressure': 128,
#   'chest_pain_type': 2,
#   'num_major_vessels': 0,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 0,
#   'resting_ekg_results': 2,
#   'serum_cholesterol_mg_per_dl': 308,
#   'oldpeak_eq_st_depression': 0.0,
#   'sex': 1,
#   'age': 45,
#   'max_heart_rate_achieved': 170,
#   'exercise_induced_angina': 0,
#   'heart_disease_present': 0},
#  1: {'patient_id': 'ryoo3j',
#   'slope_of_peak_exercise_st_segment': 2,
#   'thal': 'normal',
#   'resting_blood_pressure': 110,
#   'chest_pain_type': 3,
#   'num_major_vessels': 0,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 0,
#   'resting_ekg_results': 0,
#   'serum_cholesterol_mg_per_dl': 214,
#   'oldpeak_eq_st_depression': 1.6,
#   'sex': 0,
#   'age': 54,
#   'max_heart_rate_achieved': 158,
#   'exercise_induced_angina': 0,
#   'heart_disease_present': 0},
#  2: {'patient_id': 'yt1s1x',
#   'slope_of_peak_exercise_st_segment': 1,
#   'thal': 'normal',
#   'resting_blood_pressure': 125,
#   'chest_pain_type': 4,
#   'num_major_vessels': 3,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 0,
#   'resting_ekg_results': 2,
#   'serum_cholesterol_mg_per_dl': 304,
#   'oldpeak_eq_st_depression': 0.0,
#   'sex': 1,
#   'age': 77,
#   'max_heart_rate_achieved': 162,
#   'exercise_induced_angina': 1,
#   'heart_disease_present': 1},
#  3: {'patient_id': 'l2xjde',
#   'slope_of_peak_exercise_st_segment': 1,
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': 152,
#   'chest_pain_type': 4,
#   'num_major_vessels': 0,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 0,
#   'resting_ekg_results': 0,
#   'serum_cholesterol_mg_per_dl': 223,
#   'oldpeak_eq_st_depression': 0.0,
#   'sex': 1,
#   'age': 40,
#   'max_heart_rate_achieved': 181,
#   'exercise_induced_angina': 0,
#   'heart_disease_present': 1},
#  4: {'patient_id': 'oyt4ek',
#   'slope_of_peak_exercise_st_segment': 3,
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': 178,
#   'chest_pain_type': 1,
#   'num_major_vessels': 0,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 0,
#   'resting_ekg_results': 2,
#   'serum_cholesterol_mg_per_dl': 270,
#   'oldpeak_eq_st_depression': 4.2,
#   'sex': 1,
#   'age': 59,
#   'max_heart_rate_achieved': 145,
#   'exercise_induced_angina': 0,
#   'heart_disease_present': 0},
#  5: {'patient_id': 'ldukkw',
#   'slope_of_peak_exercise_st_segment': 1,
#   'thal': 'normal',
#   'resting_blood_pressure': 130,
#   'chest_pain_type': 3,
#   'num_major_vessels': 0,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 0,
#   'resting_ekg_results': 0,
#   'serum_cholesterol_mg_per_dl': 180,
#   'oldpeak_eq_st_depression': 0.0,
#   'sex': 1,
#   'age': 42,
#   'max_heart_rate_achieved': 150,
#   'exercise_induced_angina': 0,
#   'heart_disease_present': 0},
#  6: {'patient_id': '2gbyh9',
#   'slope_of_peak_exercise_st_segment': 2,
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': 150,
#   'chest_pain_type': 4,
#   'num_major_vessels': 2,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 0,
#   'resting_ekg_results': 2,
#   'serum_cholesterol_mg_per_dl': 258,
#   'oldpeak_eq_st_depression': 2.6,
#   'sex': 0,
#   'age': 60,
#   'max_heart_rate_achieved': 157,
#   'exercise_induced_angina': 0,
#   'heart_disease_present': 1},
#  7: {'patient_id': 'daa9kp',
#   'slope_of_peak_exercise_st_segment': 2,
#   'thal': 'fixed_defect',
#   'resting_blood_pressure': 150,
#   'chest_pain_type': 4,
#   'num_major_vessels': 1,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 0,
#   'resting_ekg_results': 2,
#   'serum_cholesterol_mg_per_dl': 276,
#   'oldpeak_eq_st_depression': 0.6,
#   'sex': 1,
#   'age': 57,
#   'max_heart_rate_achieved': 112,
#   'exercise_induced_angina': 1,
#   'heart_disease_present': 1},
#  8: {'patient_id': '3nwy2n',
#   'slope_of_peak_exercise_st_segment': 3,
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': 170,
#   'chest_pain_type': 4,
#   'num_major_vessels': 0,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 0,
#   'resting_ekg_results': 2,
#   'serum_cholesterol_mg_per_dl': 326,
#   'oldpeak_eq_st_depression': 3.4,
#   'sex': 1,
#   'age': 59,
#   'max_heart_rate_achieved': 140,
#   'exercise_induced_angina': 1,
#   'heart_disease_present': 1},
#  9: {'patient_id': '1r508r',
#   'slope_of_peak_exercise_st_segment': 2,
#   'thal': 'normal',
#   'resting_blood_pressure': 120,
#   'chest_pain_type': 3,
#   'num_major_vessels': 0,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 0,
#   'resting_ekg_results': 0,
#   'serum_cholesterol_mg_per_dl': 219,
#   'oldpeak_eq_st_depression': 1.6,
#   'sex': 0,
#   'age': 50,
#   'max_heart_rate_achieved': 158,
#   'exercise_induced_angina': 0,
#   'heart_disease_present': 0},
#  10: {'patient_id': 'ldg4b9',
#   'slope_of_peak_exercise_st_segment': 2,
#   'thal': 'normal',
#   'resting_blood_pressure': 120,
#   'chest_pain_type': 4,
#   'num_major_vessels': 0,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 0,
#   'resting_ekg_results': 2,
#   'serum_cholesterol_mg_per_dl': 302,
#   'oldpeak_eq_st_depression': 0.4,
#   'sex': 1,
#   'age': 66,
#   'max_heart_rate_achieved': 151,
#   'exercise_induced_angina': 0,
#   'heart_disease_present': 0},
#  11: {'patient_id': 'xc17yq',
#   'slope_of_peak_exercise_st_segment': 1,
#   'thal': 'normal',
#   'resting_blood_pressure': 140,
#   'chest_pain_type': 4,
#   'num_major_vessels': 0,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 0,
#   'resting_ekg_results': 0,
#   'serum_cholesterol_mg_per_dl': 226,
#   'oldpeak_eq_st_depression': 0.0,
#   'sex': 1,
#   'age': 42,
#   'max_heart_rate_achieved': 178,
#   'exercise_induced_angina': 0,
#   'heart_disease_present': 0},
#  12: {'patient_id': 'mpggsq',
#   'slope_of_peak_exercise_st_segment': 1,
#   'thal': 'normal',
#   'resting_blood_pressure': 140,
#   'chest_pain_type': 3,
#   'num_major_vessels': 0,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 0,
#   'resting_ekg_results': 0,
#   'serum_cholesterol_mg_per_dl': 335,
#   'oldpeak_eq_st_depression': 0.0,
#   'sex': 1,
#   'age': 64,
#   'max_heart_rate_achieved': 158,
#   'exercise_induced_angina': 0,
#   'heart_disease_present': 1},
#  13: {'patient_id': 'zlyac8',
#   'slope_of_peak_exercise_st_segment': 2,
#   'thal': 'normal',
#   'resting_blood_pressure': 138,
#   'chest_pain_type': 4,
#   'num_major_vessels': 0,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 0,
#   'resting_ekg_results': 2,
#   'serum_cholesterol_mg_per_dl': 236,
#   'oldpeak_eq_st_depression': 0.2,
#   'sex': 0,
#   'age': 45,
#   'max_heart_rate_achieved': 152,
#   'exercise_induced_angina': 1,
#   'heart_disease_present': 0},
#  14: {'patient_id': 'f06u72',
#   'slope_of_peak_exercise_st_segment': 2,
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': 120,
#   'chest_pain_type': 1,
#   'num_major_vessels': 0,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 0,
#   'resting_ekg_results': 0,
#   'serum_cholesterol_mg_per_dl': 231,
#   'oldpeak_eq_st_depression': 3.8,
#   'sex': 1,
#   'age': 38,
#   'max_heart_rate_achieved': 182,
#   'exercise_induced_angina': 1,
#   'heart_disease_present': 1},
#  15: {'patient_id': '2fv3rc',
#   'slope_of_peak_exercise_st_segment': 2,
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': 144,
#   'chest_pain_type': 4,
#   'num_major_vessels': 0,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 0,
#   'resting_ekg_results': 2,
#   'serum_cholesterol_mg_per_dl': 200,
#   'oldpeak_eq_st_depression': 0.9,
#   'sex': 1,
#   'age': 50,
#   'max_heart_rate_achieved': 126,
#   'exercise_induced_angina': 1,
#   'heart_disease_present': 1},
#  16: {'patient_id': 'qyrkxn',
#   'slope_of_peak_exercise_st_segment': 2,
#   'thal': 'normal',
#   'resting_blood_pressure': 130,
#   'chest_pain_type': 2,
#   'num_major_vessels': 0,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 0,
#   'resting_ekg_results': 2,
#   'serum_cholesterol_mg_per_dl': 234,
#   'oldpeak_eq_st_depression': 0.6,
#   'sex': 0,
#   'age': 45,
#   'max_heart_rate_achieved': 175,
#   'exercise_induced_angina': 0,
#   'heart_disease_present': 0},
#  17: {'patient_id': '237mql',
#   'slope_of_peak_exercise_st_segment': 1,
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': 130,
#   'chest_pain_type': 4,
#   'num_major_vessels': 1,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 0,
#   'resting_ekg_results': 0,
#   'serum_cholesterol_mg_per_dl': 253,
#   'oldpeak_eq_st_depression': 1.4,
#   'sex': 1,
#   'age': 60,
#   'max_heart_rate_achieved': 144,
#   'exercise_induced_angina': 1,
#   'heart_disease_present': 1},
#  18: {'patient_id': 'mc750a',
#   'slope_of_peak_exercise_st_segment': 1,
#   'thal': 'normal',
#   'resting_blood_pressure': 130,
#   'chest_pain_type': 2,
#   'num_major_vessels': 0,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 0,
#   'resting_ekg_results': 2,
#   'serum_cholesterol_mg_per_dl': 204,
#   'oldpeak_eq_st_depression': 0.0,
#   'sex': 1,
#   'age': 29,
#   'max_heart_rate_achieved': 202,
#   'exercise_induced_angina': 0,
#   'heart_disease_present': 0},
#  19: {'patient_id': '30v796',
#   'slope_of_peak_exercise_st_segment': 1,
#   'thal': 'normal',
#   'resting_blood_pressure': 136,
#   'chest_pain_type': 2,
#   'num_major_vessels': 2,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 1,
#   'resting_ekg_results': 2,
#   'serum_cholesterol_mg_per_dl': 319,
#   'oldpeak_eq_st_depression': 0.0,
#   'sex': 0,
#   'age': 58,
#   'max_heart_rate_achieved': 152,
#   'exercise_induced_angina': 0,
#   'heart_disease_present': 1},
#  20: {'patient_id': 'cvux3j',
#   'slope_of_peak_exercise_st_segment': 1,
#   'thal': 'normal',
#   'resting_blood_pressure': 160,
#   'chest_pain_type': 2,
#   'num_major_vessels': 2,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 0,
#   'resting_ekg_results': 0,
#   'serum_cholesterol_mg_per_dl': 302,
#   'oldpeak_eq_st_depression': 0.4,
#   'sex': 0,
#   'age': 71,
#   'max_heart_rate_achieved': 162,
#   'exercise_induced_angina': 0,
#   'heart_disease_present': 0},
#  21: {'patient_id': 'k8899q',
#   'slope_of_peak_exercise_st_segment': 1,
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': 108,
#   'chest_pain_type': 4,
#   'num_major_vessels': 3,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 1,
#   'resting_ekg_results': 0,
#   'serum_cholesterol_mg_per_dl': 233,
#   'oldpeak_eq_st_depression': 0.1,
#   'sex': 1,
#   'age': 52,
#   'max_heart_rate_achieved': 147,
#   'exercise_induced_angina': 0,
#   'heart_disease_present': 0},
#  22: {'patient_id': 'jhdvtb',
#   'slope_of_peak_exercise_st_segment': 1,
#   'thal': 'normal',
#   'resting_blood_pressure': 106,
#   'chest_pain_type': 4,
#   'num_major_vessels': 2,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 0,
#   'resting_ekg_results': 0,
#   'serum_cholesterol_mg_per_dl': 223,
#   'oldpeak_eq_st_depression': 0.3,
#   'sex': 0,
#   'age': 67,
#   'max_heart_rate_achieved': 142,
#   'exercise_induced_angina': 0,
#   'heart_disease_present': 0},
#  23: {'patient_id': '5g9v0h',
#   'slope_of_peak_exercise_st_segment': 1,
#   'thal': 'fixed_defect',
#   'resting_blood_pressure': 160,
#   'chest_pain_type': 4,
#   'num_major_vessels': 0,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 0,
#   'resting_ekg_results': 2,
#   'serum_cholesterol_mg_per_dl': 228,
#   'oldpeak_eq_st_depression': 2.3,
#   'sex': 1,
#   'age': 66,
#   'max_heart_rate_achieved': 138,
#   'exercise_induced_angina': 0,
#   'heart_disease_present': 0},
#  24: {'patient_id': '83asqd',
#   'slope_of_peak_exercise_st_segment': 1,
#   'thal': 'normal',
#   'resting_blood_pressure': 156,
#   'chest_pain_type': 2,
#   'num_major_vessels': 0,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 0,
#   'resting_ekg_results': 2,
#   'serum_cholesterol_mg_per_dl': 245,
#   'oldpeak_eq_st_depression': 0.0,
#   'sex': 1,
#   'age': 70,
#   'max_heart_rate_achieved': 143,
#   'exercise_induced_angina': 0,
#   'heart_disease_present': 0},
#  25: {'patient_id': 'gla0im',
#   'slope_of_peak_exercise_st_segment': 2,
#   'thal': 'normal',
#   'resting_blood_pressure': 120,
#   'chest_pain_type': 3,
#   'num_major_vessels': 0,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 0,
#   'resting_ekg_results': 2,
#   'serum_cholesterol_mg_per_dl': 211,
#   'oldpeak_eq_st_depression': 1.5,
#   'sex': 0,
#   'age': 68,
#   'max_heart_rate_achieved': 115,
#   'exercise_induced_angina': 0,
#   'heart_disease_present': 0},
#  26: {'patient_id': 'zzmfh7',
#   'slope_of_peak_exercise_st_segment': 1,
#   'thal': 'normal',
#   'resting_blood_pressure': 128,
#   'chest_pain_type': 4,
#   'num_major_vessels': 1,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 0,
#   'resting_ekg_results': 2,
#   'serum_cholesterol_mg_per_dl': 303,
#   'oldpeak_eq_st_depression': 0.0,
#   'sex': 0,
#   'age': 57,
#   'max_heart_rate_achieved': 159,
#   'exercise_induced_angina': 0,
#   'heart_disease_present': 0},
#  27: {'patient_id': 'f4g1ay',
#   'slope_of_peak_exercise_st_segment': 1,
#   'thal': 'normal',
#   'resting_blood_pressure': 128,
#   'chest_pain_type': 2,
#   'num_major_vessels': 0,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 1,
#   'resting_ekg_results': 0,
#   'serum_cholesterol_mg_per_dl': 205,
#   'oldpeak_eq_st_depression': 0.0,
#   'sex': 1,
#   'age': 52,
#   'max_heart_rate_achieved': 184,
#   'exercise_induced_angina': 0,
#   'heart_disease_present': 0},
#  28: {'patient_id': 'lek9q9',
#   'slope_of_peak_exercise_st_segment': 2,
#   'thal': 'normal',
#   'resting_blood_pressure': 140,
#   'chest_pain_type': 3,
#   'num_major_vessels': 0,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 0,
#   'resting_ekg_results': 2,
#   'serum_cholesterol_mg_per_dl': 185,
#   'oldpeak_eq_st_depression': 3.0,
#   'sex': 1,
#   'age': 60,
#   'max_heart_rate_achieved': 155,
#   'exercise_induced_angina': 0,
#   'heart_disease_present': 1},
#  29: {'patient_id': '8265rl',
#   'slope_of_peak_exercise_st_segment': 1,
#   'thal': 'normal',
#   'resting_blood_pressure': 110,
#   'chest_pain_type': 3,
#   'num_major_vessels': 0,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 0,
#   'resting_ekg_results': 0,
#   'serum_cholesterol_mg_per_dl': 175,
#   'oldpeak_eq_st_depression': 0.6,
#   'sex': 1,
#   'age': 51,
#   'max_heart_rate_achieved': 123,
#   'exercise_induced_angina': 0,
#   'heart_disease_present': 0},
#  30: {'patient_id': '6017a1',
#   'slope_of_peak_exercise_st_segment': 2,
#   'thal': 'normal',
#   'resting_blood_pressure': 130,
#   'chest_pain_type': 3,
#   'num_major_vessels': 0,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 0,
#   'resting_ekg_results': 2,
#   'serum_cholesterol_mg_per_dl': 214,
#   'oldpeak_eq_st_depression': 2.0,
#   'sex': 1,
#   'age': 41,
#   'max_heart_rate_achieved': 168,
#   'exercise_induced_angina': 0,
#   'heart_disease_present': 0},
#  31: {'patient_id': 'z7xkou',
#   'slope_of_peak_exercise_st_segment': 2,
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': 150,
#   'chest_pain_type': 4,
#   'num_major_vessels': 3,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 0,
#   'resting_ekg_results': 2,
#   'serum_cholesterol_mg_per_dl': 225,
#   'oldpeak_eq_st_depression': 1.0,
#   'sex': 0,
#   'age': 65,
#   'max_heart_rate_achieved': 114,
#   'exercise_induced_angina': 0,
#   'heart_disease_present': 1},
#  32: {'patient_id': 'k7ef7h',
#   'slope_of_peak_exercise_st_segment': 3,
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': 140,
#   'chest_pain_type': 4,
#   'num_major_vessels': 0,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 1,
#   'resting_ekg_results': 2,
#   'serum_cholesterol_mg_per_dl': 203,
#   'oldpeak_eq_st_depression': 3.1,
#   'sex': 1,
#   'age': 53,
#   'max_heart_rate_achieved': 155,
#   'exercise_induced_angina': 1,
#   'heart_disease_present': 1},
#  33: {'patient_id': '0n5fu0',
#   'slope_of_peak_exercise_st_segment': 1,
#   'thal': 'normal',
#   'resting_blood_pressure': 180,
#   'chest_pain_type': 4,
#   'num_major_vessels': 0,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 0,
#   'resting_ekg_results': 0,
#   'serum_cholesterol_mg_per_dl': 325,
#   'oldpeak_eq_st_depression': 0.0,
#   'sex': 0,
#   'age': 64,
#   'max_heart_rate_achieved': 154,
#   'exercise_induced_angina': 1,
#   'heart_disease_present': 0},
#  34: {'patient_id': '55xksg',
#   'slope_of_peak_exercise_st_segment': 2,
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': 112,
#   'chest_pain_type': 3,
#   'num_major_vessels': 1,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 0,
#   'resting_ekg_results': 2,
#   'serum_cholesterol_mg_per_dl': 230,
#   'oldpeak_eq_st_depression': 2.5,
#   'sex': 1,
#   'age': 58,
#   'max_heart_rate_achieved': 165,
#   'exercise_induced_angina': 0,
#   'heart_disease_present': 1},
#  35: {'patient_id': 'pjgqa3',
#   'slope_of_peak_exercise_st_segment': 1,
#   'thal': 'normal',
#   'resting_blood_pressure': 122,
#   'chest_pain_type': 4,
#   'num_major_vessels': 0,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 0,
#   'resting_ekg_results': 2,
#   'serum_cholesterol_mg_per_dl': 222,
#   'oldpeak_eq_st_depression': 0.0,
#   'sex': 1,
#   'age': 48,
#   'max_heart_rate_achieved': 186,
#   'exercise_induced_angina': 0,
#   'heart_disease_present': 0},
#  36: {'patient_id': 'xkdz7j',
#   'slope_of_peak_exercise_st_segment': 1,
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': 150,
#   'chest_pain_type': 3,
#   'num_major_vessels': 1,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 1,
#   'resting_ekg_results': 0,
#   'serum_cholesterol_mg_per_dl': 126,
#   'oldpeak_eq_st_depression': 0.2,
#   'sex': 1,
#   'age': 57,
#   'max_heart_rate_achieved': 173,
#   'exercise_induced_angina': 0,
#   'heart_disease_present': 0},
#  37: {'patient_id': 'tpuevg',
#   'slope_of_peak_exercise_st_segment': 1,
#   'thal': 'normal',
#   'resting_blood_pressure': 124,
#   'chest_pain_type': 4,
#   'num_major_vessels': 0,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 0,
#   'resting_ekg_results': 0,
#   'serum_cholesterol_mg_per_dl': 209,
#   'oldpeak_eq_st_depression': 0.0,
#   'sex': 0,
#   'age': 62,
#   'max_heart_rate_achieved': 163,
#   'exercise_induced_angina': 0,
#   'heart_disease_present': 0},
#  38: {'patient_id': 'ascl42',
#   'slope_of_peak_exercise_st_segment': 1,
#   'thal': 'normal',
#   'resting_blood_pressure': 120,
#   'chest_pain_type': 2,
#   'num_major_vessels': 1,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 0,
#   'resting_ekg_results': 2,
#   'serum_cholesterol_mg_per_dl': 269,
#   'oldpeak_eq_st_depression': 0.2,
#   'sex': 0,
#   'age': 74,
#   'max_heart_rate_achieved': 121,
#   'exercise_induced_angina': 1,
#   'heart_disease_present': 0},
#  39: {'patient_id': '1xwoe6',
#   'slope_of_peak_exercise_st_segment': 1,
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': 128,
#   'chest_pain_type': 4,
#   'num_major_vessels': 1,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 0,
#   'resting_ekg_results': 0,
#   'serum_cholesterol_mg_per_dl': 255,
#   'oldpeak_eq_st_depression': 0.0,
#   'sex': 1,
#   'age': 52,
#   'max_heart_rate_achieved': 161,
#   'exercise_induced_angina': 1,
#   'heart_disease_present': 1},
#  40: {'patient_id': 'ty4ik8',
#   'slope_of_peak_exercise_st_segment': 2,
#   'thal': 'normal',
#   'resting_blood_pressure': 150,
#   'chest_pain_type': 3,
#   'num_major_vessels': 0,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 1,
#   'resting_ekg_results': 0,
#   'serum_cholesterol_mg_per_dl': 243,
#   'oldpeak_eq_st_depression': 1.0,
#   'sex': 1,
#   'age': 61,
#   'max_heart_rate_achieved': 137,
#   'exercise_induced_angina': 1,
#   'heart_disease_present': 0},
#  41: {'patient_id': 'gx6yxl',
#   'slope_of_peak_exercise_st_segment': 1,
#   'thal': 'normal',
#   'resting_blood_pressure': 135,
#   'chest_pain_type': 3,
#   'num_major_vessels': 0,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 0,
#   'resting_ekg_results': 2,
#   'serum_cholesterol_mg_per_dl': 252,
#   'oldpeak_eq_st_depression': 0.0,
#   'sex': 0,
#   'age': 63,
#   'max_heart_rate_achieved': 172,
#   'exercise_induced_angina': 0,
#   'heart_disease_present': 0},
#  42: {'patient_id': 'hlmts5',
#   'slope_of_peak_exercise_st_segment': 1,
#   'thal': 'normal',
#   'resting_blood_pressure': 110,
#   'chest_pain_type': 3,
#   'num_major_vessels': 1,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 1,
#   'resting_ekg_results': 2,
#   'serum_cholesterol_mg_per_dl': 265,
#   'oldpeak_eq_st_depression': 0.0,
#   'sex': 0,
#   'age': 71,
#   'max_heart_rate_achieved': 130,
#   'exercise_induced_angina': 0,
#   'heart_disease_present': 0},
#  43: {'patient_id': 'yx0q6k',
#   'slope_of_peak_exercise_st_segment': 1,
#   'thal': 'normal',
#   'resting_blood_pressure': 140,
#   'chest_pain_type': 3,
#   'num_major_vessels': 1,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 1,
#   'resting_ekg_results': 2,
#   'serum_cholesterol_mg_per_dl': 417,
#   'oldpeak_eq_st_depression': 0.8,
#   'sex': 0,
#   'age': 65,
#   'max_heart_rate_achieved': 157,
#   'exercise_induced_angina': 0,
#   'heart_disease_present': 0},
#  44: {'patient_id': 'ep1o51',
#   'slope_of_peak_exercise_st_segment': 1,
#   'thal': 'normal',
#   'resting_blood_pressure': 108,
#   'chest_pain_type': 3,
#   'num_major_vessels': 0,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 0,
#   'resting_ekg_results': 2,
#   'serum_cholesterol_mg_per_dl': 267,
#   'oldpeak_eq_st_depression': 0.0,
#   'sex': 0,
#   'age': 54,
#   'max_heart_rate_achieved': 167,
#   'exercise_induced_angina': 0,
#   'heart_disease_present': 0},
#  45: {'patient_id': 'gj1e5z',
#   'slope_of_peak_exercise_st_segment': 1,
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': 124,
#   'chest_pain_type': 2,
#   'num_major_vessels': 0,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 0,
#   'resting_ekg_results': 0,
#   'serum_cholesterol_mg_per_dl': 261,
#   'oldpeak_eq_st_depression': 0.3,
#   'sex': 1,
#   'age': 57,
#   'max_heart_rate_achieved': 141,
#   'exercise_induced_angina': 0,
#   'heart_disease_present': 1},
#  46: {'patient_id': '6219kl',
#   'slope_of_peak_exercise_st_segment': 2,
#   'thal': 'normal',
#   'resting_blood_pressure': 125,
#   'chest_pain_type': 3,
#   'num_major_vessels': 0,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 1,
#   'resting_ekg_results': 2,
#   'serum_cholesterol_mg_per_dl': 245,
#   'oldpeak_eq_st_depression': 2.4,
#   'sex': 1,
#   'age': 51,
#   'max_heart_rate_achieved': 166,
#   'exercise_induced_angina': 0,
#   'heart_disease_present': 0},
#  47: {'patient_id': 'rp9g6x',
#   'slope_of_peak_exercise_st_segment': 2,
#   'thal': 'normal',
#   'resting_blood_pressure': 112,
#   'chest_pain_type': 4,
#   'num_major_vessels': 0,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 0,
#   'resting_ekg_results': 0,
#   'serum_cholesterol_mg_per_dl': 149,
#   'oldpeak_eq_st_depression': 1.6,
#   'sex': 0,
#   'age': 71,
#   'max_heart_rate_achieved': 125,
#   'exercise_induced_angina': 0,
#   'heart_disease_present': 0},
#  48: {'patient_id': '1aeaff',
#   'slope_of_peak_exercise_st_segment': 2,
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': 120,
#   'chest_pain_type': 2,
#   'num_major_vessels': 1,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 0,
#   'resting_ekg_results': 2,
#   'serum_cholesterol_mg_per_dl': 281,
#   'oldpeak_eq_st_depression': 1.4,
#   'sex': 1,
#   'age': 62,
#   'max_heart_rate_achieved': 103,
#   'exercise_induced_angina': 0,
#   'heart_disease_present': 1},
#  49: {'patient_id': 'y3prof',
#   'slope_of_peak_exercise_st_segment': 1,
#   'thal': 'normal',
#   'resting_blood_pressure': 105,
#   'chest_pain_type': 2,
#   'num_major_vessels': 0,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 0,
#   'resting_ekg_results': 0,
#   'serum_cholesterol_mg_per_dl': 204,
#   'oldpeak_eq_st_depression': 0.0,
#   'sex': 0,
#   'age': 46,
#   'max_heart_rate_achieved': 172,
#   'exercise_induced_angina': 0,
#   'heart_disease_present': 0},
#  50: {'patient_id': '3drd48',
#   'slope_of_peak_exercise_st_segment': 2,
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': 140,
#   'chest_pain_type': 4,
#   'num_major_vessels': 2,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 0,
#   'resting_ekg_results': 0,
#   'serum_cholesterol_mg_per_dl': 311,
#   'oldpeak_eq_st_depression': 1.8,
#   'sex': 1,
#   'age': 46,
#   'max_heart_rate_achieved': 120,
#   'exercise_induced_angina': 1,
#   'heart_disease_present': 1},
#  51: {'patient_id': 'ejo7p3',
#   'slope_of_peak_exercise_st_segment': 1,
#   'thal': 'normal',
#   'resting_blood_pressure': 130,
#   'chest_pain_type': 3,
#   'num_major_vessels': 1,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 0,
#   'resting_ekg_results': 0,
#   'serum_cholesterol_mg_per_dl': 315,
#   'oldpeak_eq_st_depression': 1.9,
#   'sex': 1,
#   'age': 43,
#   'max_heart_rate_achieved': 162,
#   'exercise_induced_angina': 0,
#   'heart_disease_present': 0},
#  52: {'patient_id': 'r7y4i1',
#   'slope_of_peak_exercise_st_segment': 1,
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': 130,
#   'chest_pain_type': 4,
#   'num_major_vessels': 3,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 1,
#   'resting_ekg_results': 2,
#   'serum_cholesterol_mg_per_dl': 330,
#   'oldpeak_eq_st_depression': 1.8,
#   'sex': 1,
#   'age': 63,
#   'max_heart_rate_achieved': 132,
#   'exercise_induced_angina': 1,
#   'heart_disease_present': 1},
#  53: {'patient_id': 'mznwxv',
#   'slope_of_peak_exercise_st_segment': 2,
#   'thal': 'fixed_defect',
#   'resting_blood_pressure': 130,
#   'chest_pain_type': 3,
#   'num_major_vessels': 1,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 1,
#   'resting_ekg_results': 2,
#   'serum_cholesterol_mg_per_dl': 256,
#   'oldpeak_eq_st_depression': 0.6,
#   'sex': 1,
#   'age': 56,
#   'max_heart_rate_achieved': 142,
#   'exercise_induced_angina': 1,
#   'heart_disease_present': 1},
#  54: {'patient_id': '27oevk',
#   'slope_of_peak_exercise_st_segment': 1,
#   'thal': 'normal',
#   'resting_blood_pressure': 130,
#   'chest_pain_type': 4,
#   'num_major_vessels': 0,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 0,
#   'resting_ekg_results': 2,
#   'serum_cholesterol_mg_per_dl': 330,
#   'oldpeak_eq_st_depression': 0.0,
#   'sex': 0,
#   'age': 61,
#   'max_heart_rate_achieved': 169,
#   'exercise_induced_angina': 0,
#   'heart_disease_present': 1},
#  55: {'patient_id': 'jwqi3k',
#   'slope_of_peak_exercise_st_segment': 1,
#   'thal': 'normal',
#   'resting_blood_pressure': 130,
#   'chest_pain_type': 3,
#   'num_major_vessels': 0,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 0,
#   'resting_ekg_results': 0,
#   'serum_cholesterol_mg_per_dl': 233,
#   'oldpeak_eq_st_depression': 0.4,
#   'sex': 1,
#   'age': 44,
#   'max_heart_rate_achieved': 179,
#   'exercise_induced_angina': 1,
#   'heart_disease_present': 0},
#  56: {'patient_id': '328lkl',
#   'slope_of_peak_exercise_st_segment': 2,
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': 110,
#   'chest_pain_type': 4,
#   'num_major_vessels': 1,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 0,
#   'resting_ekg_results': 0,
#   'serum_cholesterol_mg_per_dl': 239,
#   'oldpeak_eq_st_depression': 2.8,
#   'sex': 1,
#   'age': 54,
#   'max_heart_rate_achieved': 126,
#   'exercise_induced_angina': 1,
#   'heart_disease_present': 1},
#  57: {'patient_id': 'tlk9o8',
#   'slope_of_peak_exercise_st_segment': 2,
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': 120,
#   'chest_pain_type': 4,
#   'num_major_vessels': 2,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 0,
#   'resting_ekg_results': 0,
#   'serum_cholesterol_mg_per_dl': 267,
#   'oldpeak_eq_st_depression': 1.8,
#   'sex': 1,
#   'age': 62,
#   'max_heart_rate_achieved': 99,
#   'exercise_induced_angina': 1,
#   'heart_disease_present': 1},
#  58: {'patient_id': 'aq2vrq',
#   'slope_of_peak_exercise_st_segment': 1,
#   'thal': 'normal',
#   'resting_blood_pressure': 120,
#   'chest_pain_type': 2,
#   'num_major_vessels': 0,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 0,
#   'resting_ekg_results': 0,
#   'serum_cholesterol_mg_per_dl': 295,
#   'oldpeak_eq_st_depression': 0.0,
#   'sex': 1,
#   'age': 42,
#   'max_heart_rate_achieved': 162,
#   'exercise_induced_angina': 0,
#   'heart_disease_present': 0},
#  59: {'patient_id': 'ilogfb',
#   'slope_of_peak_exercise_st_segment': 1,
#   'thal': 'normal',
#   'resting_blood_pressure': 110,
#   'chest_pain_type': 4,
#   'num_major_vessels': 1,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 0,
#   'resting_ekg_results': 2,
#   'serum_cholesterol_mg_per_dl': 197,
#   'oldpeak_eq_st_depression': 0.0,
#   'sex': 1,
#   'age': 44,
#   'max_heart_rate_achieved': 177,
#   'exercise_induced_angina': 0,
#   'heart_disease_present': 1},
#  60: {'patient_id': 'rv6siv',
#   'slope_of_peak_exercise_st_segment': 2,
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': 115,
#   'chest_pain_type': 3,
#   'num_major_vessels': 0,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 0,
#   'resting_ekg_results': 2,
#   'serum_cholesterol_mg_per_dl': 564,
#   'oldpeak_eq_st_depression': 1.6,
#   'sex': 0,
#   'age': 67,
#   'max_heart_rate_achieved': 160,
#   'exercise_induced_angina': 0,
#   'heart_disease_present': 0},
#  61: {'patient_id': 'm2a4i9',
#   'slope_of_peak_exercise_st_segment': 2,
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': 130,
#   'chest_pain_type': 4,
#   'num_major_vessels': 0,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 0,
#   'resting_ekg_results': 0,
#   'serum_cholesterol_mg_per_dl': 305,
#   'oldpeak_eq_st_depression': 1.2,
#   'sex': 0,
#   'age': 51,
#   'max_heart_rate_achieved': 142,
#   'exercise_induced_angina': 1,
#   'heart_disease_present': 1},
#  62: {'patient_id': 'pwigd8',
#   'slope_of_peak_exercise_st_segment': 3,
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': 130,
#   'chest_pain_type': 4,
#   'num_major_vessels': 0,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 1,
#   'resting_ekg_results': 2,
#   'serum_cholesterol_mg_per_dl': 283,
#   'oldpeak_eq_st_depression': 1.6,
#   'sex': 1,
#   'age': 56,
#   'max_heart_rate_achieved': 103,
#   'exercise_induced_angina': 1,
#   'heart_disease_present': 1},
#  63: {'patient_id': 'qwapdq',
#   'slope_of_peak_exercise_st_segment': 2,
#   'thal': 'normal',
#   'resting_blood_pressure': 112,
#   'chest_pain_type': 2,
#   'num_major_vessels': 0,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 0,
#   'resting_ekg_results': 0,
#   'serum_cholesterol_mg_per_dl': 160,
#   'oldpeak_eq_st_depression': 0.0,
#   'sex': 0,
#   'age': 45,
#   'max_heart_rate_achieved': 138,
#   'exercise_induced_angina': 0,
#   'heart_disease_present': 0},
#  64: {'patient_id': '4sd1xn',
#   'slope_of_peak_exercise_st_segment': 1,
#   'thal': 'normal',
#   'resting_blood_pressure': 110,
#   'chest_pain_type': 4,
#   'num_major_vessels': 0,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 0,
#   'resting_ekg_results': 2,
#   'serum_cholesterol_mg_per_dl': 254,
#   'oldpeak_eq_st_depression': 0.0,
#   'sex': 0,
#   'age': 50,
#   'max_heart_rate_achieved': 159,
#   'exercise_induced_angina': 0,
#   'heart_disease_present': 0},
#  65: {'patient_id': 'nck22c',
#   'slope_of_peak_exercise_st_segment': 1,
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': 126,
#   'chest_pain_type': 4,
#   'num_major_vessels': 0,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 0,
#   'resting_ekg_results': 2,
#   'serum_cholesterol_mg_per_dl': 282,
#   'oldpeak_eq_st_depression': 0.0,
#   'sex': 1,
#   'age': 35,
#   'max_heart_rate_achieved': 156,
#   'exercise_induced_angina': 1,
#   'heart_disease_present': 1},
#  66: {'patient_id': 'm6zksp',
#   'slope_of_peak_exercise_st_segment': 2,
#   'thal': 'normal',
#   'resting_blood_pressure': 130,
#   'chest_pain_type': 4,
#   'num_major_vessels': 3,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 0,
#   'resting_ekg_results': 2,
#   'serum_cholesterol_mg_per_dl': 322,
#   'oldpeak_eq_st_depression': 2.4,
#   'sex': 1,
#   'age': 70,
#   'max_heart_rate_achieved': 109,
#   'exercise_induced_angina': 0,
#   'heart_disease_present': 1},
#  67: {'patient_id': 'f70grj',
#   'slope_of_peak_exercise_st_segment': 2,
#   'thal': 'normal',
#   'resting_blood_pressure': 115,
#   'chest_pain_type': 4,
#   'num_major_vessels': 0,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 0,
#   'resting_ekg_results': 0,
#   'serum_cholesterol_mg_per_dl': 303,
#   'oldpeak_eq_st_depression': 1.2,
#   'sex': 1,
#   'age': 43,
#   'max_heart_rate_achieved': 181,
#   'exercise_induced_angina': 0,
#   'heart_disease_present': 0},
#  68: {'patient_id': 'k1art8',
#   'slope_of_peak_exercise_st_segment': 2,
#   'thal': 'normal',
#   'resting_blood_pressure': 135,
#   'chest_pain_type': 2,
#   'num_major_vessels': 0,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 0,
#   'resting_ekg_results': 2,
#   'serum_cholesterol_mg_per_dl': 250,
#   'oldpeak_eq_st_depression': 1.4,
#   'sex': 0,
#   'age': 55,
#   'max_heart_rate_achieved': 161,
#   'exercise_induced_angina': 0,
#   'heart_disease_present': 0},
#  69: {'patient_id': 'mcwqgs',
#   'slope_of_peak_exercise_st_segment': 2,
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': 120,
#   'chest_pain_type': 3,
#   'num_major_vessels': 3,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 0,
#   'resting_ekg_results': 0,
#   'serum_cholesterol_mg_per_dl': 188,
#   'oldpeak_eq_st_depression': 2.0,
#   'sex': 1,
#   'age': 49,
#   'max_heart_rate_achieved': 139,
#   'exercise_induced_angina': 0,
#   'heart_disease_present': 1},
#  70: {'patient_id': '3jsjqk',
#   'slope_of_peak_exercise_st_segment': 1,
#   'thal': 'normal',
#   'resting_blood_pressure': 120,
#   'chest_pain_type': 2,
#   'num_major_vessels': 0,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 0,
#   'resting_ekg_results': 0,
#   'serum_cholesterol_mg_per_dl': 220,
#   'oldpeak_eq_st_depression': 0.0,
#   'sex': 1,
#   'age': 44,
#   'max_heart_rate_achieved': 170,
#   'exercise_induced_angina': 0,
#   'heart_disease_present': 0},
#  71: {'patient_id': 'ik7hfs',
#   'slope_of_peak_exercise_st_segment': 1,
#   'thal': 'normal',
#   'resting_blood_pressure': 112,
#   'chest_pain_type': 4,
#   'num_major_vessels': 0,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 0,
#   'resting_ekg_results': 0,
#   'serum_cholesterol_mg_per_dl': 204,
#   'oldpeak_eq_st_depression': 0.1,
#   'sex': 1,
#   'age': 47,
#   'max_heart_rate_achieved': 143,
#   'exercise_induced_angina': 0,
#   'heart_disease_present': 0},
#  72: {'patient_id': 'qwj1yf',
#   'slope_of_peak_exercise_st_segment': 1,
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': 172,
#   'chest_pain_type': 3,
#   'num_major_vessels': 0,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 1,
#   'resting_ekg_results': 0,
#   'serum_cholesterol_mg_per_dl': 199,
#   'oldpeak_eq_st_depression': 0.5,
#   'sex': 1,
#   'age': 52,
#   'max_heart_rate_achieved': 162,
#   'exercise_induced_angina': 0,
#   'heart_disease_present': 0},
#  73: {'patient_id': 'qvhk9e',
#   'slope_of_peak_exercise_st_segment': 1,
#   'thal': 'normal',
#   'resting_blood_pressure': 120,
#   'chest_pain_type': 3,
#   'num_major_vessels': 0,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 0,
#   'resting_ekg_results': 0,
#   'serum_cholesterol_mg_per_dl': 215,
#   'oldpeak_eq_st_depression': 0.0,
#   'sex': 0,
#   'age': 37,
#   'max_heart_rate_achieved': 170,
#   'exercise_induced_angina': 0,
#   'heart_disease_present': 0},
#  74: {'patient_id': 'igwnqo',
#   'slope_of_peak_exercise_st_segment': 2,
#   'thal': 'fixed_defect',
#   'resting_blood_pressure': 126,
#   'chest_pain_type': 3,
#   'num_major_vessels': 1,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 1,
#   'resting_ekg_results': 0,
#   'serum_cholesterol_mg_per_dl': 218,
#   'oldpeak_eq_st_depression': 2.2,
#   'sex': 1,
#   'age': 59,
#   'max_heart_rate_achieved': 134,
#   'exercise_induced_angina': 0,
#   'heart_disease_present': 1},
#  75: {'patient_id': '4v0q7o',
#   'slope_of_peak_exercise_st_segment': 2,
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': 178,
#   'chest_pain_type': 4,
#   'num_major_vessels': 2,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 1,
#   'resting_ekg_results': 0,
#   'serum_cholesterol_mg_per_dl': 228,
#   'oldpeak_eq_st_depression': 1.0,
#   'sex': 0,
#   'age': 66,
#   'max_heart_rate_achieved': 165,
#   'exercise_induced_angina': 1,
#   'heart_disease_present': 1},
#  76: {'patient_id': 'hh2awp',
#   'slope_of_peak_exercise_st_segment': 2,
#   'thal': 'normal',
#   'resting_blood_pressure': 136,
#   'chest_pain_type': 3,
#   'num_major_vessels': 0,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 0,
#   'resting_ekg_results': 2,
#   'serum_cholesterol_mg_per_dl': 196,
#   'oldpeak_eq_st_depression': 0.1,
#   'sex': 0,
#   'age': 52,
#   'max_heart_rate_achieved': 169,
#   'exercise_induced_angina': 0,
#   'heart_disease_present': 0},
#  77: {'patient_id': 'vfjppl',
#   'slope_of_peak_exercise_st_segment': 2,
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': 124,
#   'chest_pain_type': 4,
#   'num_major_vessels': 1,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 0,
#   'resting_ekg_results': 2,
#   'serum_cholesterol_mg_per_dl': 266,
#   'oldpeak_eq_st_depression': 2.2,
#   'sex': 1,
#   'age': 54,
#   'max_heart_rate_achieved': 109,
#   'exercise_induced_angina': 1,
#   'heart_disease_present': 1},
#  78: {'patient_id': '6lu42b',
#   'slope_of_peak_exercise_st_segment': 2,
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': 145,
#   'chest_pain_type': 4,
#   'num_major_vessels': 2,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 0,
#   'resting_ekg_results': 2,
#   'serum_cholesterol_mg_per_dl': 282,
#   'oldpeak_eq_st_depression': 2.8,
#   'sex': 1,
#   'age': 60,
#   'max_heart_rate_achieved': 142,
#   'exercise_induced_angina': 1,
#   'heart_disease_present': 1},
#  79: {'patient_id': 'shiro4',
#   'slope_of_peak_exercise_st_segment': 2,
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': 130,
#   'chest_pain_type': 4,
#   'num_major_vessels': 1,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 0,
#   'resting_ekg_results': 2,
#   'serum_cholesterol_mg_per_dl': 254,
#   'oldpeak_eq_st_depression': 1.4,
#   'sex': 1,
#   'age': 63,
#   'max_heart_rate_achieved': 147,
#   'exercise_induced_angina': 0,
#   'heart_disease_present': 1},
#  80: {'patient_id': '3wl3z4',
#   'slope_of_peak_exercise_st_segment': 3,
#   'thal': 'normal',
#   'resting_blood_pressure': 130,
#   'chest_pain_type': 3,
#   'num_major_vessels': 0,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 1,
#   'resting_ekg_results': 2,
#   'serum_cholesterol_mg_per_dl': 197,
#   'oldpeak_eq_st_depression': 1.2,
#   'sex': 1,
#   'age': 53,
#   'max_heart_rate_achieved': 152,
#   'exercise_induced_angina': 0,
#   'heart_disease_present': 0},
#  81: {'patient_id': 'ebioez',
#   'slope_of_peak_exercise_st_segment': 2,
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': 120,
#   'chest_pain_type': 4,
#   'num_major_vessels': 1,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 0,
#   'resting_ekg_results': 0,
#   'serum_cholesterol_mg_per_dl': 188,
#   'oldpeak_eq_st_depression': 1.4,
#   'sex': 1,
#   'age': 54,
#   'max_heart_rate_achieved': 113,
#   'exercise_induced_angina': 0,
#   'heart_disease_present': 1},
#  82: {'patient_id': '37c0vm',
#   'slope_of_peak_exercise_st_segment': 3,
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': 110,
#   'chest_pain_type': 2,
#   'num_major_vessels': 0,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 0,
#   'resting_ekg_results': 0,
#   'serum_cholesterol_mg_per_dl': 229,
#   'oldpeak_eq_st_depression': 1.0,
#   'sex': 1,
#   'age': 48,
#   'max_heart_rate_achieved': 168,
#   'exercise_induced_angina': 0,
#   'heart_disease_present': 1},
#  83: {'patient_id': 'v52zcs',
#   'slope_of_peak_exercise_st_segment': 2,
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': 128,
#   'chest_pain_type': 4,
#   'num_major_vessels': 2,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 0,
#   'resting_ekg_results': 2,
#   'serum_cholesterol_mg_per_dl': 259,
#   'oldpeak_eq_st_depression': 3.0,
#   'sex': 1,
#   'age': 58,
#   'max_heart_rate_achieved': 130,
#   'exercise_induced_angina': 1,
#   'heart_disease_present': 1},
#  84: {'patient_id': '6nkcaw',
#   'slope_of_peak_exercise_st_segment': 1,
#   'thal': 'normal',
#   'resting_blood_pressure': 130,
#   'chest_pain_type': 3,
#   'num_major_vessels': 0,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 0,
#   'resting_ekg_results': 2,
#   'serum_cholesterol_mg_per_dl': 256,
#   'oldpeak_eq_st_depression': 0.5,
#   'sex': 0,
#   'age': 51,
#   'max_heart_rate_achieved': 149,
#   'exercise_induced_angina': 0,
#   'heart_disease_present': 0},
#  85: {'patient_id': 'hfp05i',
#   'slope_of_peak_exercise_st_segment': 1,
#   'thal': 'normal',
#   'resting_blood_pressure': 118,
#   'chest_pain_type': 3,
#   'num_major_vessels': 3,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 0,
#   'resting_ekg_results': 2,
#   'serum_cholesterol_mg_per_dl': 149,
#   'oldpeak_eq_st_depression': 0.8,
#   'sex': 1,
#   'age': 49,
#   'max_heart_rate_achieved': 126,
#   'exercise_induced_angina': 0,
#   'heart_disease_present': 1},
#  86: {'patient_id': 'grfxwd',
#   'slope_of_peak_exercise_st_segment': 1,
#   'thal': 'normal',
#   'resting_blood_pressure': 112,
#   'chest_pain_type': 3,
#   'num_major_vessels': 0,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 0,
#   'resting_ekg_results': 2,
#   'serum_cholesterol_mg_per_dl': 268,
#   'oldpeak_eq_st_depression': 0.0,
#   'sex': 0,
#   'age': 41,
#   'max_heart_rate_achieved': 172,
#   'exercise_induced_angina': 1,
#   'heart_disease_present': 0},
#  87: {'patient_id': 'bvcxah',
#   'slope_of_peak_exercise_st_segment': 1,
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': 140,
#   'chest_pain_type': 4,
#   'num_major_vessels': 1,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 0,
#   'resting_ekg_results': 0,
#   'serum_cholesterol_mg_per_dl': 177,
#   'oldpeak_eq_st_depression': 0.0,
#   'sex': 1,
#   'age': 59,
#   'max_heart_rate_achieved': 162,
#   'exercise_induced_angina': 1,
#   'heart_disease_present': 1},
#  88: {'patient_id': 'i49srr',
#   'slope_of_peak_exercise_st_segment': 1,
#   'thal': 'normal',
#   'resting_blood_pressure': 150,
#   'chest_pain_type': 3,
#   'num_major_vessels': 0,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 0,
#   'resting_ekg_results': 0,
#   'serum_cholesterol_mg_per_dl': 168,
#   'oldpeak_eq_st_depression': 1.6,
#   'sex': 1,
#   'age': 57,
#   'max_heart_rate_achieved': 174,
#   'exercise_induced_angina': 0,
#   'heart_disease_present': 0},
#  89: {'patient_id': '93dbhq',
#   'slope_of_peak_exercise_st_segment': 1,
#   'thal': 'normal',
#   'resting_blood_pressure': 130,
#   'chest_pain_type': 2,
#   'num_major_vessels': 0,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 0,
#   'resting_ekg_results': 0,
#   'serum_cholesterol_mg_per_dl': 262,
#   'oldpeak_eq_st_depression': 0.0,
#   'sex': 1,
#   'age': 55,
#   'max_heart_rate_achieved': 155,
#   'exercise_induced_angina': 0,
#   'heart_disease_present': 0},
#  90: {'patient_id': 'jscmp8',
#   'slope_of_peak_exercise_st_segment': 2,
#   'thal': 'normal',
#   'resting_blood_pressure': 134,
#   'chest_pain_type': 2,
#   'num_major_vessels': 0,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 0,
#   'resting_ekg_results': 0,
#   'serum_cholesterol_mg_per_dl': 271,
#   'oldpeak_eq_st_depression': 0.0,
#   'sex': 0,
#   'age': 49,
#   'max_heart_rate_achieved': 162,
#   'exercise_induced_angina': 0,
#   'heart_disease_present': 0},
#  91: {'patient_id': 'zaytyf',
#   'slope_of_peak_exercise_st_segment': 2,
#   'thal': 'normal',
#   'resting_blood_pressure': 100,
#   'chest_pain_type': 4,
#   'num_major_vessels': 2,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 0,
#   'resting_ekg_results': 2,
#   'serum_cholesterol_mg_per_dl': 299,
#   'oldpeak_eq_st_depression': 0.9,
#   'sex': 1,
#   'age': 67,
#   'max_heart_rate_achieved': 125,
#   'exercise_induced_angina': 1,
#   'heart_disease_present': 1},
#  92: {'patient_id': 'wze8qm',
#   'slope_of_peak_exercise_st_segment': 1,
#   'thal': 'normal',
#   'resting_blood_pressure': 135,
#   'chest_pain_type': 3,
#   'num_major_vessels': 0,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 1,
#   'resting_ekg_results': 0,
#   'serum_cholesterol_mg_per_dl': 304,
#   'oldpeak_eq_st_depression': 0.0,
#   'sex': 0,
#   'age': 54,
#   'max_heart_rate_achieved': 170,
#   'exercise_induced_angina': 0,
#   'heart_disease_present': 0},
#  93: {'patient_id': 'w3933i',
#   'slope_of_peak_exercise_st_segment': 2,
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': 140,
#   'chest_pain_type': 4,
#   'num_major_vessels': 2,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 0,
#   'resting_ekg_results': 2,
#   'serum_cholesterol_mg_per_dl': 293,
#   'oldpeak_eq_st_depression': 1.2,
#   'sex': 1,
#   'age': 60,
#   'max_heart_rate_achieved': 170,
#   'exercise_induced_angina': 0,
#   'heart_disease_present': 1},
#  94: {'patient_id': '7uch9x',
#   'slope_of_peak_exercise_st_segment': 2,
#   'thal': 'normal',
#   'resting_blood_pressure': 108,
#   'chest_pain_type': 3,
#   'num_major_vessels': 0,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 0,
#   'resting_ekg_results': 0,
#   'serum_cholesterol_mg_per_dl': 141,
#   'oldpeak_eq_st_depression': 0.6,
#   'sex': 0,
#   'age': 44,
#   'max_heart_rate_achieved': 175,
#   'exercise_induced_angina': 0,
#   'heart_disease_present': 0},
#  95: {'patient_id': 'dy5hxt',
#   'slope_of_peak_exercise_st_segment': 1,
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': 118,
#   'chest_pain_type': 3,
#   'num_major_vessels': 1,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 0,
#   'resting_ekg_results': 0,
#   'serum_cholesterol_mg_per_dl': 277,
#   'oldpeak_eq_st_depression': 1.0,
#   'sex': 1,
#   'age': 68,
#   'max_heart_rate_achieved': 151,
#   'exercise_induced_angina': 0,
#   'heart_disease_present': 0},
#  96: {'patient_id': 'c0gkqc',
#   'slope_of_peak_exercise_st_segment': 2,
#   'thal': 'fixed_defect',
#   'resting_blood_pressure': 145,
#   'chest_pain_type': 4,
#   'num_major_vessels': 2,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 0,
#   'resting_ekg_results': 2,
#   'serum_cholesterol_mg_per_dl': 212,
#   'oldpeak_eq_st_depression': 2.0,
#   'sex': 1,
#   'age': 64,
#   'max_heart_rate_achieved': 132,
#   'exercise_induced_angina': 0,
#   'heart_disease_present': 1},
#  97: {'patient_id': 'z5g5p3',
#   'slope_of_peak_exercise_st_segment': 2,
#   'thal': 'normal',
#   'resting_blood_pressure': 160,
#   'chest_pain_type': 1,
#   'num_major_vessels': 1,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 1,
#   'resting_ekg_results': 2,
#   'serum_cholesterol_mg_per_dl': 234,
#   'oldpeak_eq_st_depression': 0.1,
#   'sex': 1,
#   'age': 69,
#   'max_heart_rate_achieved': 131,
#   'exercise_induced_angina': 0,
#   'heart_disease_present': 0},
#  98: {'patient_id': 'h3uzv8',
#   'slope_of_peak_exercise_st_segment': 1,
#   'thal': 'normal',
#   'resting_blood_pressure': 155,
#   'chest_pain_type': 3,
#   'num_major_vessels': 0,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 0,
#   'resting_ekg_results': 0,
#   'serum_cholesterol_mg_per_dl': 269,
#   'oldpeak_eq_st_depression': 0.8,
#   'sex': 0,
#   'age': 65,
#   'max_heart_rate_achieved': 148,
#   'exercise_induced_angina': 0,
#   'heart_disease_present': 0},
#  99: {'patient_id': 'bthqr4',
#   'slope_of_peak_exercise_st_segment': 1,
#   'thal': 'normal',
#   'resting_blood_pressure': 150,
#   'chest_pain_type': 1,
#   'num_major_vessels': 0,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 1,
#   'resting_ekg_results': 2,
#   'serum_cholesterol_mg_per_dl': 283,
#   'oldpeak_eq_st_depression': 1.0,
#   'sex': 0,
#   'age': 58,
#   'max_heart_rate_achieved': 162,
#   'exercise_induced_angina': 0,
#   'heart_disease_present': 0},
#  100: {'patient_id': 'rfj25e',
#   'slope_of_peak_exercise_st_segment': 1,
#   'thal': 'normal',
#   'resting_blood_pressure': 140,
#   'chest_pain_type': 3,
#   'num_major_vessels': 0,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 0,
#   'resting_ekg_results': 2,
#   'serum_cholesterol_mg_per_dl': 321,
#   'oldpeak_eq_st_depression': 0.0,
#   'sex': 1,
#   'age': 39,
#   'max_heart_rate_achieved': 182,
#   'exercise_induced_angina': 0,
#   'heart_disease_present': 0},
#  101: {'patient_id': '9f92et',
#   'slope_of_peak_exercise_st_segment': 2,
#   'thal': 'normal',
#   'resting_blood_pressure': 140,
#   'chest_pain_type': 2,
#   'num_major_vessels': 0,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 0,
#   'resting_ekg_results': 2,
#   'serum_cholesterol_mg_per_dl': 294,
#   'oldpeak_eq_st_depression': 1.3,
#   'sex': 0,
#   'age': 56,
#   'max_heart_rate_achieved': 153,
#   'exercise_induced_angina': 0,
#   'heart_disease_present': 0},
#  102: {'patient_id': '24fopx',
#   'slope_of_peak_exercise_st_segment': 2,
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': 110,
#   'chest_pain_type': 4,
#   'num_major_vessels': 1,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 0,
#   'resting_ekg_results': 2,
#   'serum_cholesterol_mg_per_dl': 239,
#   'oldpeak_eq_st_depression': 1.2,
#   'sex': 1,
#   'age': 59,
#   'max_heart_rate_achieved': 142,
#   'exercise_induced_angina': 1,
#   'heart_disease_present': 1},
#  103: {'patient_id': 'ldr1mz',
#   'slope_of_peak_exercise_st_segment': 1,
#   'thal': 'normal',
#   'resting_blood_pressure': 140,
#   'chest_pain_type': 3,
#   'num_major_vessels': 1,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 0,
#   'resting_ekg_results': 2,
#   'serum_cholesterol_mg_per_dl': 308,
#   'oldpeak_eq_st_depression': 1.5,
#   'sex': 0,
#   'age': 51,
#   'max_heart_rate_achieved': 142,
#   'exercise_induced_angina': 0,
#   'heart_disease_present': 0},
#  104: {'patient_id': 'wokyol',
#   'slope_of_peak_exercise_st_segment': 1,
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': 140,
#   'chest_pain_type': 3,
#   'num_major_vessels': 0,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 0,
#   'resting_ekg_results': 0,
#   'serum_cholesterol_mg_per_dl': 313,
#   'oldpeak_eq_st_depression': 0.2,
#   'sex': 0,
#   'age': 64,
#   'max_heart_rate_achieved': 133,
#   'exercise_induced_angina': 0,
#   'heart_disease_present': 0},
#  105: {'patient_id': 'p5orwa',
#   'slope_of_peak_exercise_st_segment': 2,
#   'thal': 'normal',
#   'resting_blood_pressure': 130,
#   'chest_pain_type': 4,
#   'num_major_vessels': 2,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 0,
#   'resting_ekg_results': 0,
#   'serum_cholesterol_mg_per_dl': 303,
#   'oldpeak_eq_st_depression': 2.0,
#   'sex': 0,
#   'age': 64,
#   'max_heart_rate_achieved': 122,
#   'exercise_induced_angina': 0,
#   'heart_disease_present': 0},
#  106: {'patient_id': 's8dx1q',
#   'slope_of_peak_exercise_st_segment': 1,
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': 150,
#   'chest_pain_type': 3,
#   'num_major_vessels': 0,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 0,
#   'resting_ekg_results': 2,
#   'serum_cholesterol_mg_per_dl': 232,
#   'oldpeak_eq_st_depression': 1.6,
#   'sex': 1,
#   'age': 54,
#   'max_heart_rate_achieved': 165,
#   'exercise_induced_angina': 0,
#   'heart_disease_present': 0},
#  107: {'patient_id': '7kf275',
#   'slope_of_peak_exercise_st_segment': 2,
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': 160,
# ...
#   'fasting_blood_sugar_gt_120_mg_per_dl': 0,
#   'resting_ekg_results': 2,
#   'serum_cholesterol_mg_per_dl': 216,
#   'oldpeak_eq_st_depression': 2.2,
#   'sex': 1,
#   'age': 58,
#   'max_heart_rate_achieved': 131,
#   'exercise_induced_angina': 1,
#   'heart_disease_present': 1},
#  145: {'patient_id': 'drdvf9',
#   'slope_of_peak_exercise_st_segment': 1,
#   'thal': 'normal',
#   'resting_blood_pressure': 140,
#   'chest_pain_type': 2,
#   'num_major_vessels': 2,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 0,
#   'resting_ekg_results': 0,
#   'serum_cholesterol_mg_per_dl': 195,
#   'oldpeak_eq_st_depression': 0.0,
#   'sex': 0,
#   'age': 63,
#   'max_heart_rate_achieved': 179,
#   'exercise_induced_angina': 0,
#   'heart_disease_present': 0},
#  146: {'patient_id': 'z8yl4y',
#   'slope_of_peak_exercise_st_segment': 1,
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': 140,
#   'chest_pain_type': 1,
#   'num_major_vessels': 0,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 0,
#   'resting_ekg_results': 0,
#   'serum_cholesterol_mg_per_dl': 199,
#   'oldpeak_eq_st_depression': 1.4,
#   'sex': 1,
#   'age': 40,
#   'max_heart_rate_achieved': 178,
#   'exercise_induced_angina': 1,
#   'heart_disease_present': 0},
#  147: {'patient_id': 'mxabaz',
#   'slope_of_peak_exercise_st_segment': 2,
#   'thal': 'normal',
#   'resting_blood_pressure': 134,
#   'chest_pain_type': 1,
#   'num_major_vessels': 2,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 0,
#   'resting_ekg_results': 0,
#   'serum_cholesterol_mg_per_dl': 234,
#   'oldpeak_eq_st_depression': 2.6,
#   'sex': 1,
#   'age': 61,
#   'max_heart_rate_achieved': 145,
#   'exercise_induced_angina': 0,
#   'heart_disease_present': 1},
#  148: {'patient_id': 'cpqg4x',
#   'slope_of_peak_exercise_st_segment': 1,
#   'thal': 'normal',
#   'resting_blood_pressure': 108,
#   'chest_pain_type': 3,
#   'num_major_vessels': 0,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 0,
#   'resting_ekg_results': 0,
#   'serum_cholesterol_mg_per_dl': 243,
#   'oldpeak_eq_st_depression': 0.0,
#   'sex': 1,
#   'age': 47,
#   'max_heart_rate_achieved': 152,
#   'exercise_induced_angina': 0,
#   'heart_disease_present': 1},
#  149: {'patient_id': '8c36yw',
#   'slope_of_peak_exercise_st_segment': 2,
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': 128,
#   'chest_pain_type': 3,
#   'num_major_vessels': 1,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 0,
#   'resting_ekg_results': 2,
#   'serum_cholesterol_mg_per_dl': 229,
#   'oldpeak_eq_st_depression': 0.4,
#   'sex': 1,
#   'age': 57,
#   'max_heart_rate_achieved': 150,
#   'exercise_induced_angina': 0,
#   'heart_disease_present': 1},
#  150: {'patient_id': 'x4yp0f',
#   'slope_of_peak_exercise_st_segment': 1,
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': 108,
#   'chest_pain_type': 2,
#   'num_major_vessels': 0,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 0,
#   'resting_ekg_results': 0,
#   'serum_cholesterol_mg_per_dl': 309,
#   'oldpeak_eq_st_depression': 0.0,
#   'sex': 1,
#   'age': 54,
#   'max_heart_rate_achieved': 156,
#   'exercise_induced_angina': 0,
#   'heart_disease_present': 0},
#  151: {'patient_id': '9at0il',
#   'slope_of_peak_exercise_st_segment': 3,
#   'thal': 'normal',
#   'resting_blood_pressure': 125,
#   'chest_pain_type': 3,
#   'num_major_vessels': 1,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 0,
#   'resting_ekg_results': 2,
#   'serum_cholesterol_mg_per_dl': 273,
#   'oldpeak_eq_st_depression': 0.5,
#   'sex': 1,
#   'age': 54,
#   'max_heart_rate_achieved': 152,
#   'exercise_induced_angina': 0,
#   'heart_disease_present': 0},
#  152: {'patient_id': 'nfag5b',
#   'slope_of_peak_exercise_st_segment': 2,
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': 120,
#   'chest_pain_type': 4,
#   'num_major_vessels': 0,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 0,
#   'resting_ekg_results': 0,
#   'serum_cholesterol_mg_per_dl': 198,
#   'oldpeak_eq_st_depression': 1.6,
#   'sex': 1,
#   'age': 35,
#   'max_heart_rate_achieved': 130,
#   'exercise_induced_angina': 1,
#   'heart_disease_present': 1},
#  153: {'patient_id': 'strmq8',
#   'slope_of_peak_exercise_st_segment': 1,
#   'thal': 'normal',
#   'resting_blood_pressure': 112,
#   'chest_pain_type': 4,
#   'num_major_vessels': 1,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 0,
#   'resting_ekg_results': 2,
#   'serum_cholesterol_mg_per_dl': 290,
#   'oldpeak_eq_st_depression': 0.0,
#   'sex': 1,
#   'age': 44,
#   'max_heart_rate_achieved': 153,
#   'exercise_induced_angina': 0,
#   'heart_disease_present': 1},
#  154: {'patient_id': '43k3gx',
#   'slope_of_peak_exercise_st_segment': 2,
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': 130,
#   'chest_pain_type': 3,
#   'num_major_vessels': 1,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 0,
#   'resting_ekg_results': 0,
#   'serum_cholesterol_mg_per_dl': 263,
#   'oldpeak_eq_st_depression': 1.2,
#   'sex': 0,
#   'age': 62,
#   'max_heart_rate_achieved': 97,
#   'exercise_induced_angina': 0,
#   'heart_disease_present': 1},
#  155: {'patient_id': 'fz84ac',
#   'slope_of_peak_exercise_st_segment': 1,
#   'thal': 'normal',
#   'resting_blood_pressure': 160,
#   'chest_pain_type': 1,
#   'num_major_vessels': 0,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 0,
#   'resting_ekg_results': 2,
#   'serum_cholesterol_mg_per_dl': 273,
#   'oldpeak_eq_st_depression': 0.0,
#   'sex': 1,
#   'age': 59,
#   'max_heart_rate_achieved': 125,
#   'exercise_induced_angina': 0,
#   'heart_disease_present': 1},
#  156: {'patient_id': '02cipp',
#   'slope_of_peak_exercise_st_segment': 1,
#   'thal': 'normal',
#   'resting_blood_pressure': 140,
#   'chest_pain_type': 1,
#   'num_major_vessels': 2,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 0,
#   'resting_ekg_results': 0,
#   'serum_cholesterol_mg_per_dl': 239,
#   'oldpeak_eq_st_depression': 1.8,
#   'sex': 0,
#   'age': 69,
#   'max_heart_rate_achieved': 151,
#   'exercise_induced_angina': 0,
#   'heart_disease_present': 0},
#  157: {'patient_id': '1ennzl',
#   'slope_of_peak_exercise_st_segment': 1,
#   'thal': 'normal',
#   'resting_blood_pressure': 130,
#   'chest_pain_type': 3,
#   'num_major_vessels': 0,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 0,
#   'resting_ekg_results': 0,
#   'serum_cholesterol_mg_per_dl': 275,
#   'oldpeak_eq_st_depression': 0.2,
#   'sex': 0,
#   'age': 48,
#   'max_heart_rate_achieved': 139,
#   'exercise_induced_angina': 0,
#   'heart_disease_present': 0},
#  158: {'patient_id': 'isq8yp',
#   'slope_of_peak_exercise_st_segment': 1,
#   'thal': 'normal',
#   'resting_blood_pressure': 120,
#   'chest_pain_type': 3,
#   'num_major_vessels': 0,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 0,
#   'resting_ekg_results': 0,
#   'serum_cholesterol_mg_per_dl': 226,
#   'oldpeak_eq_st_depression': 0.0,
#   'sex': 1,
#   'age': 44,
#   'max_heart_rate_achieved': 169,
#   'exercise_induced_angina': 0,
#   'heart_disease_present': 0},
#  159: {'patient_id': 'ewckbx',
#   'slope_of_peak_exercise_st_segment': 2,
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': 130,
#   'chest_pain_type': 4,
#   'num_major_vessels': 2,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 0,
#   'resting_ekg_results': 2,
#   'serum_cholesterol_mg_per_dl': 206,
#   'oldpeak_eq_st_depression': 2.4,
#   'sex': 1,
#   'age': 60,
#   'max_heart_rate_achieved': 132,
#   'exercise_induced_angina': 1,
#   'heart_disease_present': 1},
#  160: {'patient_id': 'dtljkq',
#   'slope_of_peak_exercise_st_segment': 1,
#   'thal': 'normal',
#   'resting_blood_pressure': 130,
#   'chest_pain_type': 2,
#   'num_major_vessels': 0,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 0,
#   'resting_ekg_results': 0,
#   'serum_cholesterol_mg_per_dl': 266,
#   'oldpeak_eq_st_depression': 0.6,
#   'sex': 1,
#   'age': 49,
#   'max_heart_rate_achieved': 171,
#   'exercise_induced_angina': 0,
#   'heart_disease_present': 0},
#  161: {'patient_id': 'a2kf1z',
#   'slope_of_peak_exercise_st_segment': 1,
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': 117,
#   'chest_pain_type': 4,
#   'num_major_vessels': 2,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 1,
#   'resting_ekg_results': 0,
#   'serum_cholesterol_mg_per_dl': 230,
#   'oldpeak_eq_st_depression': 1.4,
#   'sex': 1,
#   'age': 60,
#   'max_heart_rate_achieved': 160,
#   'exercise_induced_angina': 1,
#   'heart_disease_present': 1},
#  162: {'patient_id': 'usnkhx',
#   'slope_of_peak_exercise_st_segment': 3,
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': 160,
#   'chest_pain_type': 4,
#   'num_major_vessels': 3,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 0,
#   'resting_ekg_results': 2,
#   'serum_cholesterol_mg_per_dl': 164,
#   'oldpeak_eq_st_depression': 6.2,
#   'sex': 0,
#   'age': 62,
#   'max_heart_rate_achieved': 145,
#   'exercise_induced_angina': 0,
#   'heart_disease_present': 1},
#  163: {'patient_id': 'hltlsl',
#   'slope_of_peak_exercise_st_segment': 2,
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': 142,
#   'chest_pain_type': 4,
#   'num_major_vessels': 3,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 0,
#   'resting_ekg_results': 2,
#   'serum_cholesterol_mg_per_dl': 309,
#   'oldpeak_eq_st_depression': 0.0,
#   'sex': 1,
#   'age': 45,
#   'max_heart_rate_achieved': 147,
#   'exercise_induced_angina': 1,
#   'heart_disease_present': 1},
#  164: {'patient_id': 'l0c19s',
#   'slope_of_peak_exercise_st_segment': 1,
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': 142,
#   'chest_pain_type': 4,
#   'num_major_vessels': 0,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 0,
#   'resting_ekg_results': 2,
#   'serum_cholesterol_mg_per_dl': 226,
#   'oldpeak_eq_st_depression': 0.0,
#   'sex': 1,
#   'age': 53,
#   'max_heart_rate_achieved': 111,
#   'exercise_induced_angina': 1,
#   'heart_disease_present': 0},
#  165: {'patient_id': 'lcexsf',
#   'slope_of_peak_exercise_st_segment': 1,
#   'thal': 'normal',
#   'resting_blood_pressure': 152,
#   'chest_pain_type': 3,
#   'num_major_vessels': 1,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 0,
#   'resting_ekg_results': 0,
#   'serum_cholesterol_mg_per_dl': 277,
#   'oldpeak_eq_st_depression': 0.0,
#   'sex': 0,
#   'age': 67,
#   'max_heart_rate_achieved': 172,
#   'exercise_induced_angina': 0,
#   'heart_disease_present': 0},
#  166: {'patient_id': 'y3m2bd',
#   'slope_of_peak_exercise_st_segment': 1,
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': 132,
#   'chest_pain_type': 4,
#   'num_major_vessels': 0,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 0,
#   'resting_ekg_results': 0,
#   'serum_cholesterol_mg_per_dl': 207,
#   'oldpeak_eq_st_depression': 0.0,
#   'sex': 1,
#   'age': 57,
#   'max_heart_rate_achieved': 168,
#   'exercise_induced_angina': 1,
#   'heart_disease_present': 0},
#  167: {'patient_id': 'qcjf51',
#   'slope_of_peak_exercise_st_segment': 1,
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': 120,
#   'chest_pain_type': 4,
#   'num_major_vessels': 0,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 0,
#   'resting_ekg_results': 2,
#   'serum_cholesterol_mg_per_dl': 249,
#   'oldpeak_eq_st_depression': 0.8,
#   'sex': 1,
#   'age': 46,
#   'max_heart_rate_achieved': 144,
#   'exercise_induced_angina': 0,
#   'heart_disease_present': 1},
#  168: {'patient_id': '7zbya5',
#   'slope_of_peak_exercise_st_segment': 3,
#   'thal': 'fixed_defect',
#   'resting_blood_pressure': 145,
#   'chest_pain_type': 1,
#   'num_major_vessels': 0,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 1,
#   'resting_ekg_results': 2,
#   'serum_cholesterol_mg_per_dl': 233,
#   'oldpeak_eq_st_depression': 2.3,
#   'sex': 1,
#   'age': 63,
#   'max_heart_rate_achieved': 150,
#   'exercise_induced_angina': 0,
#   'heart_disease_present': 0},
#  169: {'patient_id': '23gf0e',
#   'slope_of_peak_exercise_st_segment': 2,
#   'thal': 'normal',
#   'resting_blood_pressure': 110,
#   'chest_pain_type': 1,
#   'num_major_vessels': 0,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 0,
#   'resting_ekg_results': 2,
#   'serum_cholesterol_mg_per_dl': 211,
#   'oldpeak_eq_st_depression': 1.8,
#   'sex': 1,
#   'age': 64,
#   'max_heart_rate_achieved': 144,
#   'exercise_induced_angina': 1,
#   'heart_disease_present': 0},
#  170: {'patient_id': 'qhz9ye',
#   'slope_of_peak_exercise_st_segment': 1,
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': 150,
#   'chest_pain_type': 4,
#   'num_major_vessels': 0,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 0,
#   'resting_ekg_results': 2,
#   'serum_cholesterol_mg_per_dl': 270,
#   'oldpeak_eq_st_depression': 0.8,
#   'sex': 1,
#   'age': 58,
#   'max_heart_rate_achieved': 111,
#   'exercise_induced_angina': 1,
#   'heart_disease_present': 1},
#  171: {'patient_id': 'u25507',
#   'slope_of_peak_exercise_st_segment': 1,
#   'thal': 'normal',
#   'resting_blood_pressure': 112,
#   'chest_pain_type': 4,
#   'num_major_vessels': 1,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 0,
#   'resting_ekg_results': 2,
#   'serum_cholesterol_mg_per_dl': 212,
#   'oldpeak_eq_st_depression': 0.1,
#   'sex': 1,
#   'age': 66,
#   'max_heart_rate_achieved': 132,
#   'exercise_induced_angina': 1,
#   'heart_disease_present': 1},
#  172: {'patient_id': 'j9tw19',
#   'slope_of_peak_exercise_st_segment': 2,
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': 118,
#   'chest_pain_type': 4,
#   'num_major_vessels': 0,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 0,
#   'resting_ekg_results': 0,
#   'serum_cholesterol_mg_per_dl': 219,
#   'oldpeak_eq_st_depression': 1.2,
#   'sex': 1,
#   'age': 39,
#   'max_heart_rate_achieved': 140,
#   'exercise_induced_angina': 0,
#   'heart_disease_present': 1},
#  173: {'patient_id': '5o32oi',
#   'slope_of_peak_exercise_st_segment': 1,
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': 140,
#   'chest_pain_type': 4,
#   'num_major_vessels': 0,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 0,
#   'resting_ekg_results': 0,
#   'serum_cholesterol_mg_per_dl': 299,
#   'oldpeak_eq_st_depression': 1.6,
#   'sex': 1,
#   'age': 51,
#   'max_heart_rate_achieved': 173,
#   'exercise_induced_angina': 1,
#   'heart_disease_present': 1},
#  174: {'patient_id': 'o63ri2',
#   'slope_of_peak_exercise_st_segment': 1,
#   'thal': 'normal',
#   'resting_blood_pressure': 140,
#   'chest_pain_type': 4,
#   'num_major_vessels': 0,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 0,
#   'resting_ekg_results': 0,
#   'serum_cholesterol_mg_per_dl': 239,
#   'oldpeak_eq_st_depression': 1.2,
#   'sex': 1,
#   'age': 54,
#   'max_heart_rate_achieved': 160,
#   'exercise_induced_angina': 0,
#   'heart_disease_present': 0},
#  175: {'patient_id': '5qfar3',
#   'slope_of_peak_exercise_st_segment': 2,
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': 125,
#   'chest_pain_type': 4,
#   'num_major_vessels': 2,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 1,
#   'resting_ekg_results': 0,
#   'serum_cholesterol_mg_per_dl': 254,
#   'oldpeak_eq_st_depression': 0.2,
#   'sex': 1,
#   'age': 67,
#   'max_heart_rate_achieved': 163,
#   'exercise_induced_angina': 0,
#   'heart_disease_present': 1},
#  176: {'patient_id': '2s2b1f',
#   'slope_of_peak_exercise_st_segment': 2,
#   'thal': 'normal',
#   'resting_blood_pressure': 180,
#   'chest_pain_type': 4,
#   'num_major_vessels': 0,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 0,
#   'resting_ekg_results': 1,
#   'serum_cholesterol_mg_per_dl': 327,
#   'oldpeak_eq_st_depression': 3.4,
#   'sex': 0,
#   'age': 55,
#   'max_heart_rate_achieved': 117,
#   'exercise_induced_angina': 1,
#   'heart_disease_present': 1},
#  177: {'patient_id': 'nsd00i',
#   'slope_of_peak_exercise_st_segment': 2,
#   'thal': 'reversible_defect',
#   'resting_blood_pressure': 125,
#   'chest_pain_type': 3,
#   'num_major_vessels': 0,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 0,
#   'resting_ekg_results': 0,
#   'serum_cholesterol_mg_per_dl': 309,
#   'oldpeak_eq_st_depression': 1.8,
#   'sex': 1,
#   'age': 64,
#   'max_heart_rate_achieved': 131,
#   'exercise_induced_angina': 1,
#   'heart_disease_present': 1},
#  178: {'patient_id': '0xw93k',
#   'slope_of_peak_exercise_st_segment': 1,
#   'thal': 'normal',
#   'resting_blood_pressure': 124,
#   'chest_pain_type': 3,
#   'num_major_vessels': 2,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 1,
#   'resting_ekg_results': 0,
#   'serum_cholesterol_mg_per_dl': 255,
#   'oldpeak_eq_st_depression': 0.0,
#   'sex': 1,
#   'age': 48,
#   'max_heart_rate_achieved': 175,
#   'exercise_induced_angina': 0,
#   'heart_disease_present': 0},
#  179: {'patient_id': '2nx10r',
#   'slope_of_peak_exercise_st_segment': 1,
#   'thal': 'normal',
#   'resting_blood_pressure': 160,
#   'chest_pain_type': 3,
#   'num_major_vessels': 1,
#   'fasting_blood_sugar_gt_120_mg_per_dl': 0,
#   'resting_ekg_results': 0,
#   'serum_cholesterol_mg_per_dl': 201,
#   'oldpeak_eq_st_depression': 0.0,
#   'sex': 0,
#   'age': 54,
#   'max_heart_rate_achieved': 163,
#   'exercise_induced_angina': 0,
#   'heart_disease_present': 0}}

# %%
len(d)
# Out:
# 180
